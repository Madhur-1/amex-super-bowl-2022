# %%
import numpy as np
import pandas as pd
# library for splitting training-testing
from sklearn.model_selection import train_test_split
# library for classification
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA

from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import StandardScaler
from sklearn import pipeline
from lightgbm import LGBMClassifier

from hyperopt import tpe,hp,Trials
from hyperopt.fmin import fmin
import warnings

# %%
x_train = pd.read_feather("Data/x_train__IterativeImputer_genFeats.ftr")
x_test = pd.read_feather("Data/x_test__IterativeImputer_genFeats.ftr")

x_tr = pd.read_csv("Preds/preds_train.csv")
x_val_1 = pd.read_csv("Preds/preds_val.csv")
x_test_1 = pd.read_csv("Preds/preds_test.csv")

y_train = pd.read_csv("Data/train_y.csv")
y_test = pd.read_csv("Data/Sample_Output.csv", names = ['ID', 'Target'], header=None)

# %%
x_train_1, x_val, y_train_1, y_val = train_test_split(x_train, y_train, test_size=0.15, random_state=59, stratify=y_train)

# %%
x_train_1 = pd.concat([x_train_1.reset_index(drop=True), x_tr], axis=1)
x_val = pd.concat([x_val.reset_index(drop=True), x_val_1], axis=1)
x_test = pd.concat([x_test.reset_index(drop=True), x_test_1], axis=1)

# %%
#check if given parameter can be interpreted as a numerical value
def is_number(s):
    if s is None:
        return False
    try:
        float(s)
        return True
    except ValueError:
        return False

def convert_int_params(names, params):
    for int_type in names:
        #sometimes the parameters can be choices between options or numerical values. like "log2" vs "1-10"
        raw_val = params[int_type]
        if is_number(raw_val):
            params[int_type] = int(raw_val)
    return params

def create_fit_params(params):
    using_dart = params['boosting_type'] == "dart"
    
    fit_params = {"eval_metric": "multi_logloss"}
    if using_dart:
        n_estimators = 75
    else:
        n_estimators = 200
        fit_params["early_stopping_rounds"] = 10
    params["n_estimators"] = n_estimators
    return fit_params

def objective(params):
    warnings.filterwarnings(action='ignore', category=DeprecationWarning)
    
    int_types = ["num_leaves", "min_child_samples", "subsample_for_bin", "min_data_in_leaf"]
    params = convert_int_params(int_types, params)

    # Extract the boosting type
    params['boosting_type'] = params['boosting_type']['boosting_type']
    #    print("running with params:"+str(params))

    fit_params = create_fit_params(params)
    
    model = LGBMClassifier(**params)
    
    model.fit(x_tr, 
              y_train_1.values.reshape(-1), 
              eval_set=[(x_tr, y_train_1.values.reshape(-1)), (x_val_1, y_val.values.reshape(-1))], 
              verbose=1, **fit_params)
    
    preds_tr = model.predict(x_tr,)
    preds_val = model.predict(x_val_1)
    val_score = accuracy_score(y_val, preds_val)
    tr_score = accuracy_score(y_train_1, preds_tr)
    print(tr_score, val_score, params)
    return -1.0*val_score

def optimize(trial):
    space = {
        #this is just piling on most of the possible parameter values for LGBM
        #some of them apparently don't make sense together, but works for now.. :)
        'boosting_type': hp.choice('boosting_type',
                                   [{'boosting_type': 'gbdt',
#                                     'subsample': hp.uniform('dart_subsample', 0.5, 1)
                                     },
                                    {'boosting_type': 'dart',
#                                     'subsample': hp.uniform('dart_subsample', 0.5, 1)
                                     },
                                    {'boosting_type': 'goss'}]),
        'num_leaves': hp.quniform('num_leaves', 30, 150, 1),
        'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.2)),
        'subsample_for_bin': hp.quniform('subsample_for_bin', 20000, 300000, 20000),
        'feature_fraction': hp.uniform('feature_fraction', 0.5, 1),
        'bagging_fraction': hp.uniform('bagging_fraction', 0.5, 1), #alias "subsample"
        'min_data_in_leaf': hp.qloguniform('min_data_in_leaf', 4, 15, 1),
        'lambda_l1': hp.choice('lambda_l1', [0, hp.loguniform('lambda_l1_positive', -16, 2)]),
        'lambda_l2': hp.choice('lambda_l2', [0, hp.loguniform('lambda_l2_positive', -16, 2)]),
        'verbose': -1,
        #the LGBM parameters docs list various aliases, and the LGBM implementation seems to complain about
        #the following not being used due to other params, so trying to silence the complaints by setting to None
        'subsample': None, #overridden by bagging_fraction
        'reg_alpha': None, #overridden by lambda_l1
        'reg_lambda': None, #overridden by lambda_l2
        'min_sum_hessian_in_leaf': None, #overrides min_child_weight
        'min_child_samples': None, #overridden by min_data_in_leaf
        'colsample_bytree': None, #overridden by feature_fraction
#        'min_child_samples': hp.quniform('min_child_samples', 20, 500, 5),
        'min_child_weight': hp.loguniform('min_child_weight', -16, 5), #also aliases to min_sum_hessian
#        'reg_alpha': hp.uniform('reg_alpha', 0.0, 1.0),
#        'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0),
#        'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0),
        'objective' : "multiclass",
        "num_class" : 4,
        'num_threads' : 8
    }
    best=fmin(fn=objective,space=space,algo=tpe.suggest,trials=trial,max_evals=20,rstate=np.random.default_rng(59))
    return best

trial=Trials()
best=optimize(trial)
# Out:
#   0%|                                                                     | 0/20 [00:00<?, ?trial/s, best loss=?]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854213	valid_1's multi_logloss: 0.854375
# [2]	valid_0's multi_logloss: 0.854057	valid_1's multi_logloss: 0.854387
# [3]	valid_0's multi_logloss: 0.853908	valid_1's multi_logloss: 0.854395
# [4]	valid_0's multi_logloss: 0.853762	valid_1's multi_logloss: 0.854402
# [5]	valid_0's multi_logloss: 0.853611	valid_1's multi_logloss: 0.854405
# [6]	valid_0's multi_logloss: 0.85346	valid_1's multi_logloss: 0.854414
# [7]	valid_0's multi_logloss: 0.85331	valid_1's multi_logloss: 0.854414
# [8]	valid_0's multi_logloss: 0.853164	valid_1's multi_logloss: 0.854424
# [9]	valid_0's multi_logloss: 0.853018	valid_1's multi_logloss: 0.854422
# [10]	valid_0's multi_logloss: 0.852873	valid_1's multi_logloss: 0.854431
# [11]	valid_0's multi_logloss: 0.852735	valid_1's multi_logloss: 0.854427
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.6530367653057585, 'boosting_type': 'goss', 'colsample_bytree': None, 'feature_fraction': 0.5402084503627147, 'lambda_l1': 0, 'lambda_l2': 0.02853346827572134, 'learning_rate': 0.026826504259791908, 'min_child_samples': None, 'min_child_weight': 0.00036956898266055104, 'min_data_in_leaf': 123, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 77, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 60000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#   5%|██                                        | 1/20 [00:03<01:07,  3.56s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854363	valid_1's multi_logloss: 0.854355
# [2]	valid_0's multi_logloss: 0.85436	valid_1's multi_logloss: 0.854353
# [3]	valid_0's multi_logloss: 0.854357	valid_1's multi_logloss: 0.854351
# [4]	valid_0's multi_logloss: 0.854354	valid_1's multi_logloss: 0.854352
# [5]	valid_0's multi_logloss: 0.854352	valid_1's multi_logloss: 0.854352
# [6]	valid_0's multi_logloss: 0.85435	valid_1's multi_logloss: 0.854351
# [7]	valid_0's multi_logloss: 0.854348	valid_1's multi_logloss: 0.854352
# [63]	valid_0's multi_logloss: 0.895965	valid_1's multi_logloss: 0.897296
# [64]	valid_0's multi_logloss: 0.895468	valid_1's multi_logloss: 0.896779
# [65]	valid_0's multi_logloss: 0.89561	valid_1's multi_logloss: 0.896903
# [66]	valid_0's multi_logloss: 0.893078	valid_1's multi_logloss: 0.894394
# [67]	valid_0's multi_logloss: 0.890689	valid_1's multi_logloss: 0.892029
# [68]	valid_0's multi_logloss: 0.888433	valid_1's multi_logloss: 0.889795
# [69]	valid_0's multi_logloss: 0.888361	valid_1's multi_logloss: 0.889702
# [70]	valid_0's multi_logloss: 0.888125	valid_1's multi_logloss: 0.889455
# [71]	valid_0's multi_logloss: 0.887609	valid_1's multi_logloss: 0.888923
# [72]	valid_0's multi_logloss: 0.885531	valid_1's multi_logloss: 0.886868
# [73]	valid_0's multi_logloss: 0.883571	valid_1's multi_logloss: 0.88493
# [74]	valid_0's multi_logloss: 0.883719	valid_1's multi_logloss: 0.885063
# [75]	valid_0's multi_logloss: 0.881863	valid_1's multi_logloss: 0.883227
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.9037778055261227, 'boosting_type': 'dart', 'colsample_bytree': None, 'feature_fraction': 0.9533634871827803, 'lambda_l1': 0.05880970092021131, 'lambda_l2': 0, 'learning_rate': 0.02508956890463392, 'min_child_samples': None, 'min_child_weight': 4.4122243902352913e-07, 'min_data_in_leaf': 10055, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 62, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 220000, 'verbose': -1, 'n_estimators': 75}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  15%|██████▎                                   | 3/20 [00:34<04:03, 14.30s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854353	valid_1's multi_logloss: 0.854356
# [2]	valid_0's multi_logloss: 0.85434	valid_1's multi_logloss: 0.854358
# [3]	valid_0's multi_logloss: 0.854327	valid_1's multi_logloss: 0.854356
# [4]	valid_0's multi_logloss: 0.854315	valid_1's multi_logloss: 0.854355
# [5]	valid_0's multi_logloss: 0.854303	valid_1's multi_logloss: 0.854355
# [6]	valid_0's multi_logloss: 0.854291	valid_1's multi_logloss: 0.854355
# [7]	valid_0's multi_logloss: 0.85428	valid_1's multi_logloss: 0.854355
# [8]	valid_0's multi_logloss: 0.854268	valid_1's multi_logloss: 0.854357
# [9]	valid_0's multi_logloss: 0.854257	valid_1's multi_logloss: 0.854356
# [10]	valid_0's multi_logloss: 0.854246	valid_1's multi_logloss: 0.854357
# [11]	valid_0's multi_logloss: 0.854234	valid_1's multi_logloss: 0.854358
# [12]	valid_0's multi_logloss: 0.854223	valid_1's multi_logloss: 0.85436
# [13]	valid_0's multi_logloss: 0.854212	valid_1's multi_logloss: 0.85436
# [14]	valid_0's multi_logloss: 0.854201	valid_1's multi_logloss: 0.854361
# [15]	valid_0's multi_logloss: 0.854191	valid_1's multi_logloss: 0.854362
# [16]	valid_0's multi_logloss: 0.85418	valid_1's multi_logloss: 0.854363
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.8736304416214922, 'boosting_type': 'goss', 'colsample_bytree': None, 'feature_fraction': 0.9482635546439876, 'lambda_l1': 2.1087002181502683, 'lambda_l2': 0, 'learning_rate': 0.013117187016425436, 'min_child_samples': None, 'min_child_weight': 37.92314065797057, 'min_data_in_leaf': 17057, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 37, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 200000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  20%|████████▍                                 | 4/20 [00:38<02:45, 10.37s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854295	valid_1's multi_logloss: 0.854351
# [2]	valid_0's multi_logloss: 0.854222	valid_1's multi_logloss: 0.854353
# [3]	valid_0's multi_logloss: 0.854153	valid_1's multi_logloss: 0.854354
# [4]	valid_0's multi_logloss: 0.854081	valid_1's multi_logloss: 0.854351
# [5]	valid_0's multi_logloss: 0.854011	valid_1's multi_logloss: 0.854352
# [6]	valid_0's multi_logloss: 0.853944	valid_1's multi_logloss: 0.854359
# [7]	valid_0's multi_logloss: 0.853877	valid_1's multi_logloss: 0.854353
# [8]	valid_0's multi_logloss: 0.853809	valid_1's multi_logloss: 0.854351
# [9]	valid_0's multi_logloss: 0.853745	valid_1's multi_logloss: 0.854353
# [10]	valid_0's multi_logloss: 0.853681	valid_1's multi_logloss: 0.854357
# [11]	valid_0's multi_logloss: 0.853613	valid_1's multi_logloss: 0.854362
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.7302453474333799, 'boosting_type': 'goss', 'colsample_bytree': None, 'feature_fraction': 0.7994324170415164, 'lambda_l1': 3.03623173165202e-05, 'lambda_l2': 3.504002668474051e-05, 'learning_rate': 0.029843362622547696, 'min_child_samples': None, 'min_child_weight': 0.000880609252011017, 'min_data_in_leaf': 6702, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 132, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 100000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  25%|██████████▌                               | 5/20 [00:42<01:59,  7.99s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.85413	valid_1's multi_logloss: 0.854389
# [2]	valid_0's multi_logloss: 0.853892	valid_1's multi_logloss: 0.854416
# [3]	valid_0's multi_logloss: 0.853688	valid_1's multi_logloss: 0.854434
# [4]	valid_0's multi_logloss: 0.853486	valid_1's multi_logloss: 0.854472
# [5]	valid_0's multi_logloss: 0.853303	valid_1's multi_logloss: 0.854509
# [6]	valid_0's multi_logloss: 0.853103	valid_1's multi_logloss: 0.854527
# [7]	valid_0's multi_logloss: 0.853067	valid_1's multi_logloss: 0.854555
# [8]	valid_0's multi_logloss: 0.853019	valid_1's multi_logloss: 0.854606
# [9]	valid_0's multi_logloss: 0.85298	valid_1's multi_logloss: 0.854631
# [10]	valid_0's multi_logloss: 0.85295	valid_1's multi_logloss: 0.854645
# [11]	valid_0's multi_logloss: 0.852923	valid_1's multi_logloss: 0.854708
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.8258718803655605, 'boosting_type': 'goss', 'colsample_bytree': None, 'feature_fraction': 0.6324769096986069, 'lambda_l1': 0, 'lambda_l2': 5.112681023079499e-07, 'learning_rate': 0.16543309540290774, 'min_child_samples': None, 'min_child_weight': 0.005790234467065733, 'min_data_in_leaf': 10358, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 57, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 200000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  30%|████████████▌                             | 6/20 [00:45<01:28,  6.32s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854214	valid_1's multi_logloss: 0.85436
# [2]	valid_0's multi_logloss: 0.85407	valid_1's multi_logloss: 0.854356
# [3]	valid_0's multi_logloss: 0.853921	valid_1's multi_logloss: 0.854357
# [4]	valid_0's multi_logloss: 0.853771	valid_1's multi_logloss: 0.854362
# [5]	valid_0's multi_logloss: 0.853627	valid_1's multi_logloss: 0.854364
# [6]	valid_0's multi_logloss: 0.853483	valid_1's multi_logloss: 0.854369
# [44]	valid_0's multi_logloss: 0.850281	valid_1's multi_logloss: 0.854547
# [45]	valid_0's multi_logloss: 0.850165	valid_1's multi_logloss: 0.854565
# [46]	valid_0's multi_logloss: 0.856822	valid_1's multi_logloss: 0.861165
# [47]	valid_0's multi_logloss: 0.856118	valid_1's multi_logloss: 0.860562
# [48]	valid_0's multi_logloss: 0.855829	valid_1's multi_logloss: 0.86028
# [49]	valid_0's multi_logloss: 0.855791	valid_1's multi_logloss: 0.860166
# [50]	valid_0's multi_logloss: 0.855866	valid_1's multi_logloss: 0.860162
# [51]	valid_0's multi_logloss: 0.855254	valid_1's multi_logloss: 0.859655
# [52]	valid_0's multi_logloss: 0.854678	valid_1's multi_logloss: 0.859195
# [53]	valid_0's multi_logloss: 0.854767	valid_1's multi_logloss: 0.859235
# [54]	valid_0's multi_logloss: 0.854237	valid_1's multi_logloss: 0.858825
# [55]	valid_0's multi_logloss: 0.853738	valid_1's multi_logloss: 0.858435
# [56]	valid_0's multi_logloss: 0.853816	valid_1's multi_logloss: 0.858429
# [57]	valid_0's multi_logloss: 0.853356	valid_1's multi_logloss: 0.858093
# [58]	valid_0's multi_logloss: 0.870081	valid_1's multi_logloss: 0.874778
# [59]	valid_0's multi_logloss: 0.870009	valid_1's multi_logloss: 0.874629
# [60]	valid_0's multi_logloss: 0.868151	valid_1's multi_logloss: 0.872869
# [61]	valid_0's multi_logloss: 0.893107	valid_1's multi_logloss: 0.897801
# [62]	valid_0's multi_logloss: 0.889323	valid_1's multi_logloss: 0.894113
# [63]	valid_0's multi_logloss: 0.885843	valid_1's multi_logloss: 0.890718
# [64]	valid_0's multi_logloss: 0.885268	valid_1's multi_logloss: 0.890074
# [65]	valid_0's multi_logloss: 0.885485	valid_1's multi_logloss: 0.890219
# [66]	valid_0's multi_logloss: 0.882327	valid_1's multi_logloss: 0.887149
# [67]	valid_0's multi_logloss: 0.879425	valid_1's multi_logloss: 0.884333
# [68]	valid_0's multi_logloss: 0.876757	valid_1's multi_logloss: 0.881757
# [69]	valid_0's multi_logloss: 0.876734	valid_1's multi_logloss: 0.881656
# [70]	valid_0's multi_logloss: 0.876496	valid_1's multi_logloss: 0.881378
# [71]	valid_0's multi_logloss: 0.875944	valid_1's multi_logloss: 0.880773
# [72]	valid_0's multi_logloss: 0.87357	valid_1's multi_logloss: 0.878489
# [73]	valid_0's multi_logloss: 0.871388	valid_1's multi_logloss: 0.876403
# [74]	valid_0's multi_logloss: 0.871592	valid_1's multi_logloss: 0.876551
# [75]	valid_0's multi_logloss: 0.869573	valid_1's multi_logloss: 0.874626
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.9188762985491308, 'boosting_type': 'dart', 'colsample_bytree': None, 'feature_fraction': 0.6463599607934534, 'lambda_l1': 0.02224525554914679, 'lambda_l2': 0, 'learning_rate': 0.036691935902934486, 'min_child_samples': None, 'min_child_weight': 7.861358931762953e-06, 'min_data_in_leaf': 3818, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 100, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 140000, 'verbose': -1, 'n_estimators': 75}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  35%|██████████████▋                           | 7/20 [01:23<03:37, 16.75s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854274	valid_1's multi_logloss: 0.854359
# [2]	valid_0's multi_logloss: 0.854179	valid_1's multi_logloss: 0.85436
# [3]	valid_0's multi_logloss: 0.854089	valid_1's multi_logloss: 0.854365
# [4]	valid_0's multi_logloss: 0.853998	valid_1's multi_logloss: 0.854369
# [5]	valid_0's multi_logloss: 0.853905	valid_1's multi_logloss: 0.85437
# [6]	valid_0's multi_logloss: 0.853816	valid_1's multi_logloss: 0.854371
# [7]	valid_0's multi_logloss: 0.853728	valid_1's multi_logloss: 0.854371
# [8]	valid_0's multi_logloss: 0.853641	valid_1's multi_logloss: 0.854375
# [9]	valid_0's multi_logloss: 0.853552	valid_1's multi_logloss: 0.85438
# [10]	valid_0's multi_logloss: 0.853467	valid_1's multi_logloss: 0.854386
# [11]	valid_0's multi_logloss: 0.853378	valid_1's multi_logloss: 0.854385
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.9183103754017063, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.6744628299579388, 'lambda_l1': 0, 'lambda_l2': 0.010122351304944838, 'learning_rate': 0.013493464020840184, 'min_child_samples': None, 'min_child_weight': 0.000691034126093053, 'min_data_in_leaf': 129, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 91, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 120000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  40%|████████████████▊                         | 8/20 [01:26<02:28, 12.40s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.85281	valid_1's multi_logloss: 0.854483
# [2]	valid_0's multi_logloss: 0.851308	valid_1's multi_logloss: 0.854744
# [3]	valid_0's multi_logloss: 0.84989	valid_1's multi_logloss: 0.854838
# [4]	valid_0's multi_logloss: 0.848615	valid_1's multi_logloss: 0.854892
# [5]	valid_0's multi_logloss: 0.847248	valid_1's multi_logloss: 0.855044
# [6]	valid_0's multi_logloss: 0.845898	valid_1's multi_logloss: 0.855104
# [7]	valid_0's multi_logloss: 0.844587	valid_1's multi_logloss: 0.855222
# [8]	valid_0's multi_logloss: 0.845013	valid_1's multi_logloss: 0.855062
# [9]	valid_0's multi_logloss: 0.843719	valid_1's multi_logloss: 0.855171
# [10]	valid_0's multi_logloss: 0.842429	valid_1's multi_logloss: 0.855148
# [11]	valid_0's multi_logloss: 0.841248	valid_1's multi_logloss: 0.855227
# [12]	valid_0's multi_logloss: 0.841619	valid_1's multi_logloss: 0.855149
# [13]	valid_0's multi_logloss: 0.840498	valid_1's multi_logloss: 0.855211
# [14]	valid_0's multi_logloss: 0.839223	valid_1's multi_logloss: 0.855389
# [15]	valid_0's multi_logloss: 0.838106	valid_1's multi_logloss: 0.855528
# [16]	valid_0's multi_logloss: 0.836966	valid_1's multi_logloss: 0.855688
# [17]	valid_0's multi_logloss: 0.835757	valid_1's multi_logloss: 0.855738
# [18]	valid_0's multi_logloss: 0.834603	valid_1's multi_logloss: 0.85574
# [19]	valid_0's multi_logloss: 0.833443	valid_1's multi_logloss: 0.855817
# [20]	valid_0's multi_logloss: 0.832257	valid_1's multi_logloss: 0.855867
# [21]	valid_0's multi_logloss: 0.832531	valid_1's multi_logloss: 0.855806
# [22]	valid_0's multi_logloss: 0.831432	valid_1's multi_logloss: 0.855952
# [23]	valid_0's multi_logloss: 0.830264	valid_1's multi_logloss: 0.856096
# [24]	valid_0's multi_logloss: 0.829186	valid_1's multi_logloss: 0.856232
# [25]	valid_0's multi_logloss: 0.828065	valid_1's multi_logloss: 0.856356
# [26]	valid_0's multi_logloss: 0.826989	valid_1's multi_logloss: 0.856496
# [27]	valid_0's multi_logloss: 0.825869	valid_1's multi_logloss: 0.856613
# [28]	valid_0's multi_logloss: 0.826204	valid_1's multi_logloss: 0.856532
# [29]	valid_0's multi_logloss: 0.825125	valid_1's multi_logloss: 0.856706
# [30]	valid_0's multi_logloss: 0.824099	valid_1's multi_logloss: 0.856831
# [31]	valid_0's multi_logloss: 0.824042	valid_1's multi_logloss: 0.856799
# [32]	valid_0's multi_logloss: 0.822952	valid_1's multi_logloss: 0.856897
# [33]	valid_0's multi_logloss: 0.821913	valid_1's multi_logloss: 0.856934
# [34]	valid_0's multi_logloss: 0.820833	valid_1's multi_logloss: 0.857045
# [35]	valid_0's multi_logloss: 0.821312	valid_1's multi_logloss: 0.856927
# [36]	valid_0's multi_logloss: 0.821983	valid_1's multi_logloss: 0.856793
# [37]	valid_0's multi_logloss: 0.820924	valid_1's multi_logloss: 0.856864
# [38]	valid_0's multi_logloss: 0.819775	valid_1's multi_logloss: 0.856993
# [39]	valid_0's multi_logloss: 0.818754	valid_1's multi_logloss: 0.857097
# [40]	valid_0's multi_logloss: 0.818394	valid_1's multi_logloss: 0.857089
# [41]	valid_0's multi_logloss: 0.818924	valid_1's multi_logloss: 0.856988
# [42]	valid_0's multi_logloss: 0.817734	valid_1's multi_logloss: 0.856986
# [43]	valid_0's multi_logloss: 0.818235	valid_1's multi_logloss: 0.856881
# [44]	valid_0's multi_logloss: 0.817182	valid_1's multi_logloss: 0.856924
# [45]	valid_0's multi_logloss: 0.816081	valid_1's multi_logloss: 0.857101
# [46]	valid_0's multi_logloss: 0.821411	valid_1's multi_logloss: 0.861472
# [47]	valid_0's multi_logloss: 0.818705	valid_1's multi_logloss: 0.859817
# [48]	valid_0's multi_logloss: 0.817993	valid_1's multi_logloss: 0.859215
# [49]	valid_0's multi_logloss: 0.818355	valid_1's multi_logloss: 0.858915
# [50]	valid_0's multi_logloss: 0.818972	valid_1's multi_logloss: 0.858829
# [51]	valid_0's multi_logloss: 0.817226	valid_1's multi_logloss: 0.858142
# [52]	valid_0's multi_logloss: 0.815781	valid_1's multi_logloss: 0.857705
# [53]	valid_0's multi_logloss: 0.81625	valid_1's multi_logloss: 0.857723
# [54]	valid_0's multi_logloss: 0.814849	valid_1's multi_logloss: 0.857533
# [55]	valid_0's multi_logloss: 0.813588	valid_1's multi_logloss: 0.85747
# [56]	valid_0's multi_logloss: 0.814253	valid_1's multi_logloss: 0.857377
# [57]	valid_0's multi_logloss: 0.813089	valid_1's multi_logloss: 0.857362
# [58]	valid_0's multi_logloss: 0.82026	valid_1's multi_logloss: 0.863701
# [59]	valid_0's multi_logloss: 0.820668	valid_1's multi_logloss: 0.863391
# [60]	valid_0's multi_logloss: 0.817286	valid_1's multi_logloss: 0.861011
# [61]	valid_0's multi_logloss: 0.828671	valid_1's multi_logloss: 0.871784
# [46]	valid_0's multi_logloss: 0.860403	valid_1's multi_logloss: 0.860561
# [47]	valid_0's multi_logloss: 0.859488	valid_1's multi_logloss: 0.85965
# [48]	valid_0's multi_logloss: 0.859089	valid_1's multi_logloss: 0.859252
# [49]	valid_0's multi_logloss: 0.858942	valid_1's multi_logloss: 0.859102
# [50]	valid_0's multi_logloss: 0.85895	valid_1's multi_logloss: 0.859108
# [51]	valid_0's multi_logloss: 0.858246	valid_1's multi_logloss: 0.858407
# [52]	valid_0's multi_logloss: 0.857644	valid_1's multi_logloss: 0.857809
# [53]	valid_0's multi_logloss: 0.857708	valid_1's multi_logloss: 0.85787
# [54]	valid_0's multi_logloss: 0.857184	valid_1's multi_logloss: 0.85735
# [55]	valid_0's multi_logloss: 0.856738	valid_1's multi_logloss: 0.856909
# [56]	valid_0's multi_logloss: 0.856747	valid_1's multi_logloss: 0.856915
# [57]	valid_0's multi_logloss: 0.856365	valid_1's multi_logloss: 0.856535
# [58]	valid_0's multi_logloss: 0.870175	valid_1's multi_logloss: 0.870345
# [59]	valid_0's multi_logloss: 0.87	valid_1's multi_logloss: 0.870167
# [60]	valid_0's multi_logloss: 0.867731	valid_1's multi_logloss: 0.867902
# [61]	valid_0's multi_logloss: 0.888871	valid_1's multi_logloss: 0.889043
# [62]	valid_0's multi_logloss: 0.884035	valid_1's multi_logloss: 0.884211
# [63]	valid_0's multi_logloss: 0.879851	valid_1's multi_logloss: 0.880029
# [64]	valid_0's multi_logloss: 0.879106	valid_1's multi_logloss: 0.879281
# [65]	valid_0's multi_logloss: 0.87929	valid_1's multi_logloss: 0.879463
# [66]	valid_0's multi_logloss: 0.875748	valid_1's multi_logloss: 0.875923
# [67]	valid_0's multi_logloss: 0.87269	valid_1's multi_logloss: 0.872866
# [68]	valid_0's multi_logloss: 0.870051	valid_1's multi_logloss: 0.87023
# [69]	valid_0's multi_logloss: 0.869995	valid_1's multi_logloss: 0.87017
# [70]	valid_0's multi_logloss: 0.869739	valid_1's multi_logloss: 0.869913
# [71]	valid_0's multi_logloss: 0.869166	valid_1's multi_logloss: 0.869338
# [72]	valid_0's multi_logloss: 0.867016	valid_1's multi_logloss: 0.867192
# [73]	valid_0's multi_logloss: 0.865166	valid_1's multi_logloss: 0.865344
# [74]	valid_0's multi_logloss: 0.86532	valid_1's multi_logloss: 0.865497
# [75]	valid_0's multi_logloss: 0.863708	valid_1's multi_logloss: 0.863886
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.7650305183987045, 'boosting_type': 'dart', 'colsample_bytree': None, 'feature_fraction': 0.7819202362918904, 'lambda_l1': 0, 'lambda_l2': 0, 'learning_rate': 0.06005062066761176, 'min_child_samples': None, 'min_child_weight': 3.7655421286129434, 'min_data_in_leaf': 96735, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 110, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 20000, 'verbose': -1, 'n_estimators': 75}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  85%|██████████████████████████████████▊      | 17/20 [02:40<00:23,  7.90s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.854072	valid_1's multi_logloss: 0.854367
# [2]	valid_0's multi_logloss: 0.853792	valid_1's multi_logloss: 0.854377
# [3]	valid_0's multi_logloss: 0.85351	valid_1's multi_logloss: 0.854395
# [4]	valid_0's multi_logloss: 0.85325	valid_1's multi_logloss: 0.854433
# [5]	valid_0's multi_logloss: 0.852997	valid_1's multi_logloss: 0.854446
# [6]	valid_0's multi_logloss: 0.852742	valid_1's multi_logloss: 0.854465
# [7]	valid_0's multi_logloss: 0.852501	valid_1's multi_logloss: 0.854479
# [8]	valid_0's multi_logloss: 0.852248	valid_1's multi_logloss: 0.854503
# [9]	valid_0's multi_logloss: 0.852019	valid_1's multi_logloss: 0.854543
# [10]	valid_0's multi_logloss: 0.851794	valid_1's multi_logloss: 0.854554
# [11]	valid_0's multi_logloss: 0.851567	valid_1's multi_logloss: 0.854579
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.5908617913599878, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.6728581825517779, 'lambda_l1': 0, 'lambda_l2': 1.0615529139869173, 'learning_rate': 0.11591886252569034, 'min_child_samples': None, 'min_child_weight': 17.49549284958927, 'min_data_in_leaf': 5387, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 46, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 200000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  90%|████████████████████████████████████▉    | 18/20 [02:44<00:13,  6.57s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [2]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [3]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [4]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [5]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [6]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [7]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [8]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [9]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [10]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# [11]	valid_0's multi_logloss: 1.14992	valid_1's multi_logloss: 1.1499
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.7479400003646597, 'boosting_type': 'goss', 'colsample_bytree': None, 'feature_fraction': 0.5282290645702981, 'lambda_l1': 5.191540288782814e-07, 'lambda_l2': 2.288484009552648e-05, 'learning_rate': 0.14308033083169314, 'min_child_samples': None, 'min_child_weight': 1.369500515665858, 'min_data_in_leaf': 3080632, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 92, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 100000, 'verbose': -1, 'n_estimators': 200}
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
#  95%|██████████████████████████████████████▉  | 19/20 [02:45<00:04,  4.90s/trial, best loss: -0.7410694829815361]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.85436	valid_1's multi_logloss: 0.854354
# [2]	valid_0's multi_logloss: 0.854355	valid_1's multi_logloss: 0.854352
# [3]	valid_0's multi_logloss: 0.85435	valid_1's multi_logloss: 0.854354
# [4]	valid_0's multi_logloss: 0.854345	valid_1's multi_logloss: 0.854354
# [5]	valid_0's multi_logloss: 0.85434	valid_1's multi_logloss: 0.854354
# [6]	valid_0's multi_logloss: 0.854335	valid_1's multi_logloss: 0.854358
# [7]	valid_0's multi_logloss: 0.854331	valid_1's multi_logloss: 0.854359
# [8]	valid_0's multi_logloss: 0.854327	valid_1's multi_logloss: 0.854356
# [9]	valid_0's multi_logloss: 0.854324	valid_1's multi_logloss: 0.854358
# [10]	valid_0's multi_logloss: 0.85432	valid_1's multi_logloss: 0.85436
# [11]	valid_0's multi_logloss: 0.854316	valid_1's multi_logloss: 0.854359
# [12]	valid_0's multi_logloss: 0.854313	valid_1's multi_logloss: 0.854361
# 0.7410658435791999
# 0.7410694829815361
# {'bagging_fraction': 0.5250751021801847, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.9883346099002539, 'lambda_l1': 0, 'lambda_l2': 0.0002683643955968309, 'learning_rate': 0.0787506045475446, 'min_child_samples': None, 'min_child_weight': 0.003732544183266879, 'min_data_in_leaf': 124834, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 122, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 120000, 'verbose': -1, 'n_estimators': 200}
# 100%|█████████████████████████████████████████| 20/20 [02:47<00:00,  8.38s/trial, best loss: -0.7410694829815361]

# %% [markdown]
# 0.8408130723243675
# 0.818920057527202
# {'bagging_fraction': 0.7735281708228888, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.7019688791355287, 'lambda_l1': 0.0005066902069864062, 'lambda_l2': 3.374501183311695e-06, 'learning_rate': 0.04616756254060491, 'min_child_samples': None, 'min_child_weight': 3.29982863252954, 'min_data_in_leaf': 56, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 58, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 140000, 'verbose': -1, 'n_estimators': 200}

# %%
bestParams = {'bagging_fraction': 0.7735281708228888, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.7019688791355287, 'lambda_l1': 0.0005066902069864062, 'lambda_l2': 3.374501183311695e-06, 'learning_rate': 0.04616756254060491, 'min_child_samples': None, 'min_child_weight': 3.29982863252954, 'min_data_in_leaf': 56, 'min_sum_hessian_in_leaf': None, 'num_class': 4, 'num_leaves': 58, 'num_threads': 8, 'objective': 'multiclass', 'reg_alpha': None, 'reg_lambda': None, 'subsample': None, 'subsample_for_bin': 140000, 'verbose': -1, 'n_estimators': 200}

# %%
model = LGBMClassifier(**bestParams)
    
model.fit(x_train_1, 
          y_train_1.values.reshape(-1), 
          eval_set=[(x_train_1, y_train_1.values.reshape(-1)), (x_val, y_val.values.reshape(-1))], 
          verbose=1, early_stopping_rounds=10)

preds_tr = model.predict(x_train_1,)
preds_val = model.predict(x_val)
val_score = accuracy_score(y_val, preds_val)
tr_score = accuracy_score(y_train_1, preds_tr)
print(tr_score, val_score)
# Out:
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	valid_0's multi_logloss: 0.809338	valid_1's multi_logloss: 0.809506
# [2]	valid_0's multi_logloss: 0.773751	valid_1's multi_logloss: 0.774106
# [3]	valid_0's multi_logloss: 0.744055	valid_1's multi_logloss: 0.744591
# [4]	valid_0's multi_logloss: 0.718559	valid_1's multi_logloss: 0.71929
# [5]	valid_0's multi_logloss: 0.696536	valid_1's multi_logloss: 0.697507
# [6]	valid_0's multi_logloss: 0.677077	valid_1's multi_logloss: 0.678234
# [7]	valid_0's multi_logloss: 0.659963	valid_1's multi_logloss: 0.661316
# [8]	valid_0's multi_logloss: 0.644045	valid_1's multi_logloss: 0.645566
# [9]	valid_0's multi_logloss: 0.629871	valid_1's multi_logloss: 0.631601
# [10]	valid_0's multi_logloss: 0.617197	valid_1's multi_logloss: 0.619105
# [11]	valid_0's multi_logloss: 0.60545	valid_1's multi_logloss: 0.60754
# [12]	valid_0's multi_logloss: 0.594796	valid_1's multi_logloss: 0.597066
# [13]	valid_0's multi_logloss: 0.584992	valid_1's multi_logloss: 0.587412
# [14]	valid_0's multi_logloss: 0.575775	valid_1's multi_logloss: 0.578385
# [15]	valid_0's multi_logloss: 0.567373	valid_1's multi_logloss: 0.570171
# [16]	valid_0's multi_logloss: 0.559636	valid_1's multi_logloss: 0.562556
# [17]	valid_0's multi_logloss: 0.552516	valid_1's multi_logloss: 0.555646
# [18]	valid_0's multi_logloss: 0.545982	valid_1's multi_logloss: 0.549297
# [19]	valid_0's multi_logloss: 0.53996	valid_1's multi_logloss: 0.543444
# [20]	valid_0's multi_logloss: 0.534365	valid_1's multi_logloss: 0.538002
# [21]	valid_0's multi_logloss: 0.52911	valid_1's multi_logloss: 0.532945
# [22]	valid_0's multi_logloss: 0.524258	valid_1's multi_logloss: 0.528307
# [23]	valid_0's multi_logloss: 0.519683	valid_1's multi_logloss: 0.523953
# [24]	valid_0's multi_logloss: 0.515376	valid_1's multi_logloss: 0.519856
# [25]	valid_0's multi_logloss: 0.511404	valid_1's multi_logloss: 0.516104
# [26]	valid_0's multi_logloss: 0.507672	valid_1's multi_logloss: 0.512547
# [27]	valid_0's multi_logloss: 0.504192	valid_1's multi_logloss: 0.509223
# [28]	valid_0's multi_logloss: 0.500911	valid_1's multi_logloss: 0.506151
# [29]	valid_0's multi_logloss: 0.49782	valid_1's multi_logloss: 0.50324
# [30]	valid_0's multi_logloss: 0.494896	valid_1's multi_logloss: 0.500565
# [31]	valid_0's multi_logloss: 0.492156	valid_1's multi_logloss: 0.498042
# [32]	valid_0's multi_logloss: 0.4896	valid_1's multi_logloss: 0.495663
# [33]	valid_0's multi_logloss: 0.487162	valid_1's multi_logloss: 0.493439
# [34]	valid_0's multi_logloss: 0.484881	valid_1's multi_logloss: 0.491363
# [35]	valid_0's multi_logloss: 0.482751	valid_1's multi_logloss: 0.489443
# [36]	valid_0's multi_logloss: 0.48073	valid_1's multi_logloss: 0.487647
# [37]	valid_0's multi_logloss: 0.478802	valid_1's multi_logloss: 0.485919
# [38]	valid_0's multi_logloss: 0.476965	valid_1's multi_logloss: 0.484295
# [39]	valid_0's multi_logloss: 0.475237	valid_1's multi_logloss: 0.482771
# [40]	valid_0's multi_logloss: 0.473568	valid_1's multi_logloss: 0.481357
# [41]	valid_0's multi_logloss: 0.471982	valid_1's multi_logloss: 0.480009
# [42]	valid_0's multi_logloss: 0.470457	valid_1's multi_logloss: 0.478691
# [43]	valid_0's multi_logloss: 0.469009	valid_1's multi_logloss: 0.477467
# [44]	valid_0's multi_logloss: 0.467637	valid_1's multi_logloss: 0.476328
# [45]	valid_0's multi_logloss: 0.466309	valid_1's multi_logloss: 0.475247
# [46]	valid_0's multi_logloss: 0.465054	valid_1's multi_logloss: 0.474236
# [47]	valid_0's multi_logloss: 0.463855	valid_1's multi_logloss: 0.473288
# [48]	valid_0's multi_logloss: 0.462724	valid_1's multi_logloss: 0.472371
# [49]	valid_0's multi_logloss: 0.46159	valid_1's multi_logloss: 0.47148
# [50]	valid_0's multi_logloss: 0.46054	valid_1's multi_logloss: 0.470702
# [51]	valid_0's multi_logloss: 0.45952	valid_1's multi_logloss: 0.469914
# [52]	valid_0's multi_logloss: 0.45853	valid_1's multi_logloss: 0.469161
# [53]	valid_0's multi_logloss: 0.457567	valid_1's multi_logloss: 0.468433
# [54]	valid_0's multi_logloss: 0.456675	valid_1's multi_logloss: 0.467779
# [55]	valid_0's multi_logloss: 0.45581	valid_1's multi_logloss: 0.467145
# [56]	valid_0's multi_logloss: 0.454924	valid_1's multi_logloss: 0.466536
# [57]	valid_0's multi_logloss: 0.454082	valid_1's multi_logloss: 0.465939
# [58]	valid_0's multi_logloss: 0.453284	valid_1's multi_logloss: 0.465388
# [59]	valid_0's multi_logloss: 0.452493	valid_1's multi_logloss: 0.464845
# [60]	valid_0's multi_logloss: 0.451731	valid_1's multi_logloss: 0.464305
# [61]	valid_0's multi_logloss: 0.450971	valid_1's multi_logloss: 0.463803
# [62]	valid_0's multi_logloss: 0.450248	valid_1's multi_logloss: 0.46333
# [63]	valid_0's multi_logloss: 0.449566	valid_1's multi_logloss: 0.462892
# [64]	valid_0's multi_logloss: 0.448902	valid_1's multi_logloss: 0.462492
# [65]	valid_0's multi_logloss: 0.448228	valid_1's multi_logloss: 0.462064
# [66]	valid_0's multi_logloss: 0.447585	valid_1's multi_logloss: 0.461673
# [67]	valid_0's multi_logloss: 0.446949	valid_1's multi_logloss: 0.461301
# [68]	valid_0's multi_logloss: 0.44635	valid_1's multi_logloss: 0.460964
# [69]	valid_0's multi_logloss: 0.445753	valid_1's multi_logloss: 0.460633
# [70]	valid_0's multi_logloss: 0.445157	valid_1's multi_logloss: 0.460324
# [71]	valid_0's multi_logloss: 0.444573	valid_1's multi_logloss: 0.459998
# [72]	valid_0's multi_logloss: 0.444018	valid_1's multi_logloss: 0.459707
# [73]	valid_0's multi_logloss: 0.443458	valid_1's multi_logloss: 0.459418
# [74]	valid_0's multi_logloss: 0.442908	valid_1's multi_logloss: 0.459141
# [75]	valid_0's multi_logloss: 0.442373	valid_1's multi_logloss: 0.458848
# [76]	valid_0's multi_logloss: 0.441814	valid_1's multi_logloss: 0.458567
# [77]	valid_0's multi_logloss: 0.44129	valid_1's multi_logloss: 0.458315
# [78]	valid_0's multi_logloss: 0.440773	valid_1's multi_logloss: 0.45804
# [79]	valid_0's multi_logloss: 0.440274	valid_1's multi_logloss: 0.457797
# [80]	valid_0's multi_logloss: 0.439767	valid_1's multi_logloss: 0.457518
# [81]	valid_0's multi_logloss: 0.439283	valid_1's multi_logloss: 0.457284
# [82]	valid_0's multi_logloss: 0.438781	valid_1's multi_logloss: 0.457069
# [83]	valid_0's multi_logloss: 0.438298	valid_1's multi_logloss: 0.456804
# [84]	valid_0's multi_logloss: 0.43781	valid_1's multi_logloss: 0.456568
# [85]	valid_0's multi_logloss: 0.437332	valid_1's multi_logloss: 0.456349
# [86]	valid_0's multi_logloss: 0.436867	valid_1's multi_logloss: 0.456171
# [87]	valid_0's multi_logloss: 0.43639	valid_1's multi_logloss: 0.455978
# [88]	valid_0's multi_logloss: 0.435932	valid_1's multi_logloss: 0.455804
# [89]	valid_0's multi_logloss: 0.435502	valid_1's multi_logloss: 0.455664
# [90]	valid_0's multi_logloss: 0.435054	valid_1's multi_logloss: 0.455488
# [91]	valid_0's multi_logloss: 0.434617	valid_1's multi_logloss: 0.455342
# [92]	valid_0's multi_logloss: 0.434196	valid_1's multi_logloss: 0.455192
# [93]	valid_0's multi_logloss: 0.433765	valid_1's multi_logloss: 0.455046
# [94]	valid_0's multi_logloss: 0.433354	valid_1's multi_logloss: 0.454896
# [95]	valid_0's multi_logloss: 0.43294	valid_1's multi_logloss: 0.454767
# [96]	valid_0's multi_logloss: 0.432512	valid_1's multi_logloss: 0.454639
# [97]	valid_0's multi_logloss: 0.432099	valid_1's multi_logloss: 0.454521
# [98]	valid_0's multi_logloss: 0.431698	valid_1's multi_logloss: 0.454387
# [99]	valid_0's multi_logloss: 0.431271	valid_1's multi_logloss: 0.454251
# [100]	valid_0's multi_logloss: 0.430872	valid_1's multi_logloss: 0.454118
# [101]	valid_0's multi_logloss: 0.430465	valid_1's multi_logloss: 0.453977
# [102]	valid_0's multi_logloss: 0.43005	valid_1's multi_logloss: 0.453857
# [103]	valid_0's multi_logloss: 0.429663	valid_1's multi_logloss: 0.453751
# [104]	valid_0's multi_logloss: 0.429282	valid_1's multi_logloss: 0.453654
# [105]	valid_0's multi_logloss: 0.428876	valid_1's multi_logloss: 0.45354
# [106]	valid_0's multi_logloss: 0.428477	valid_1's multi_logloss: 0.453416
# [107]	valid_0's multi_logloss: 0.428097	valid_1's multi_logloss: 0.453318
# [108]	valid_0's multi_logloss: 0.427726	valid_1's multi_logloss: 0.453212
# [109]	valid_0's multi_logloss: 0.427354	valid_1's multi_logloss: 0.453122
# [110]	valid_0's multi_logloss: 0.426982	valid_1's multi_logloss: 0.453041
# [111]	valid_0's multi_logloss: 0.42662	valid_1's multi_logloss: 0.45297
# [112]	valid_0's multi_logloss: 0.426265	valid_1's multi_logloss: 0.452868
# [113]	valid_0's multi_logloss: 0.425889	valid_1's multi_logloss: 0.452787
# [114]	valid_0's multi_logloss: 0.425519	valid_1's multi_logloss: 0.45266
# [115]	valid_0's multi_logloss: 0.425133	valid_1's multi_logloss: 0.452572
# [116]	valid_0's multi_logloss: 0.424785	valid_1's multi_logloss: 0.452483
# [117]	valid_0's multi_logloss: 0.424411	valid_1's multi_logloss: 0.452387
# [118]	valid_0's multi_logloss: 0.424037	valid_1's multi_logloss: 0.452296
# [119]	valid_0's multi_logloss: 0.42368	valid_1's multi_logloss: 0.452195
# [120]	valid_0's multi_logloss: 0.423339	valid_1's multi_logloss: 0.452136
# [121]	valid_0's multi_logloss: 0.422981	valid_1's multi_logloss: 0.452047
# [122]	valid_0's multi_logloss: 0.422626	valid_1's multi_logloss: 0.451973
# [123]	valid_0's multi_logloss: 0.422282	valid_1's multi_logloss: 0.45189
# [124]	valid_0's multi_logloss: 0.421934	valid_1's multi_logloss: 0.451832
# [125]	valid_0's multi_logloss: 0.421609	valid_1's multi_logloss: 0.451761
# [126]	valid_0's multi_logloss: 0.421243	valid_1's multi_logloss: 0.451692
# [127]	valid_0's multi_logloss: 0.420899	valid_1's multi_logloss: 0.451609
# [128]	valid_0's multi_logloss: 0.42057	valid_1's multi_logloss: 0.451531
# [129]	valid_0's multi_logloss: 0.420248	valid_1's multi_logloss: 0.451467
# [130]	valid_0's multi_logloss: 0.419892	valid_1's multi_logloss: 0.451379
# [131]	valid_0's multi_logloss: 0.41957	valid_1's multi_logloss: 0.451339
# [132]	valid_0's multi_logloss: 0.419218	valid_1's multi_logloss: 0.451241
# [133]	valid_0's multi_logloss: 0.418896	valid_1's multi_logloss: 0.451183
# [134]	valid_0's multi_logloss: 0.418557	valid_1's multi_logloss: 0.451105
# [135]	valid_0's multi_logloss: 0.41822	valid_1's multi_logloss: 0.451043
# [136]	valid_0's multi_logloss: 0.417899	valid_1's multi_logloss: 0.450975
# [137]	valid_0's multi_logloss: 0.417595	valid_1's multi_logloss: 0.450919
# [138]	valid_0's multi_logloss: 0.417282	valid_1's multi_logloss: 0.450862
# [139]	valid_0's multi_logloss: 0.416966	valid_1's multi_logloss: 0.450791
# [140]	valid_0's multi_logloss: 0.41664	valid_1's multi_logloss: 0.450741
# [141]	valid_0's multi_logloss: 0.416337	valid_1's multi_logloss: 0.450682
# [142]	valid_0's multi_logloss: 0.416019	valid_1's multi_logloss: 0.450638
# [143]	valid_0's multi_logloss: 0.415703	valid_1's multi_logloss: 0.450581
# [144]	valid_0's multi_logloss: 0.415413	valid_1's multi_logloss: 0.450545
# [145]	valid_0's multi_logloss: 0.41512	valid_1's multi_logloss: 0.450502
# [146]	valid_0's multi_logloss: 0.414817	valid_1's multi_logloss: 0.45048
# [147]	valid_0's multi_logloss: 0.414502	valid_1's multi_logloss: 0.450433
# [148]	valid_0's multi_logloss: 0.414189	valid_1's multi_logloss: 0.450376
# [149]	valid_0's multi_logloss: 0.413863	valid_1's multi_logloss: 0.450317
# [150]	valid_0's multi_logloss: 0.413573	valid_1's multi_logloss: 0.450302
# [151]	valid_0's multi_logloss: 0.413276	valid_1's multi_logloss: 0.450256
# [152]	valid_0's multi_logloss: 0.41296	valid_1's multi_logloss: 0.450219
# [153]	valid_0's multi_logloss: 0.412665	valid_1's multi_logloss: 0.450184
# [154]	valid_0's multi_logloss: 0.41235	valid_1's multi_logloss: 0.450135
# [155]	valid_0's multi_logloss: 0.41206	valid_1's multi_logloss: 0.450101
# [156]	valid_0's multi_logloss: 0.411771	valid_1's multi_logloss: 0.450072
# [157]	valid_0's multi_logloss: 0.411493	valid_1's multi_logloss: 0.45005
# [158]	valid_0's multi_logloss: 0.411206	valid_1's multi_logloss: 0.450022
# [159]	valid_0's multi_logloss: 0.410916	valid_1's multi_logloss: 0.449996
# [160]	valid_0's multi_logloss: 0.410613	valid_1's multi_logloss: 0.449951
# [161]	valid_0's multi_logloss: 0.410317	valid_1's multi_logloss: 0.449905
# [162]	valid_0's multi_logloss: 0.410036	valid_1's multi_logloss: 0.449863
# [163]	valid_0's multi_logloss: 0.409743	valid_1's multi_logloss: 0.449843
# [164]	valid_0's multi_logloss: 0.409454	valid_1's multi_logloss: 0.449805
# [165]	valid_0's multi_logloss: 0.409174	valid_1's multi_logloss: 0.449769
# [166]	valid_0's multi_logloss: 0.408889	valid_1's multi_logloss: 0.449736
# [167]	valid_0's multi_logloss: 0.408588	valid_1's multi_logloss: 0.449693
# [168]	valid_0's multi_logloss: 0.408301	valid_1's multi_logloss: 0.449658
# [169]	valid_0's multi_logloss: 0.408025	valid_1's multi_logloss: 0.449637
# [170]	valid_0's multi_logloss: 0.407745	valid_1's multi_logloss: 0.449605
# [171]	valid_0's multi_logloss: 0.407464	valid_1's multi_logloss: 0.449586
# [172]	valid_0's multi_logloss: 0.407178	valid_1's multi_logloss: 0.449577
# [173]	valid_0's multi_logloss: 0.406909	valid_1's multi_logloss: 0.449564
# [174]	valid_0's multi_logloss: 0.406631	valid_1's multi_logloss: 0.449536
# [175]	valid_0's multi_logloss: 0.406352	valid_1's multi_logloss: 0.449516
# [176]	valid_0's multi_logloss: 0.406076	valid_1's multi_logloss: 0.449492
# [177]	valid_0's multi_logloss: 0.405806	valid_1's multi_logloss: 0.449483
# [178]	valid_0's multi_logloss: 0.405533	valid_1's multi_logloss: 0.449452
# [179]	valid_0's multi_logloss: 0.405259	valid_1's multi_logloss: 0.44943
# [180]	valid_0's multi_logloss: 0.405	valid_1's multi_logloss: 0.449398
# [181]	valid_0's multi_logloss: 0.404727	valid_1's multi_logloss: 0.449377
# [182]	valid_0's multi_logloss: 0.40445	valid_1's multi_logloss: 0.449339
# [183]	valid_0's multi_logloss: 0.404165	valid_1's multi_logloss: 0.449312
# [184]	valid_0's multi_logloss: 0.403871	valid_1's multi_logloss: 0.449284
# [185]	valid_0's multi_logloss: 0.4036	valid_1's multi_logloss: 0.449245
# [186]	valid_0's multi_logloss: 0.40334	valid_1's multi_logloss: 0.449218
# [187]	valid_0's multi_logloss: 0.403055	valid_1's multi_logloss: 0.449182
# [188]	valid_0's multi_logloss: 0.402801	valid_1's multi_logloss: 0.449172
# [189]	valid_0's multi_logloss: 0.40253	valid_1's multi_logloss: 0.449171
# [190]	valid_0's multi_logloss: 0.402266	valid_1's multi_logloss: 0.449139
# [191]	valid_0's multi_logloss: 0.402001	valid_1's multi_logloss: 0.449075
# [192]	valid_0's multi_logloss: 0.401744	valid_1's multi_logloss: 0.449061
# [193]	valid_0's multi_logloss: 0.401487	valid_1's multi_logloss: 0.449063
# [194]	valid_0's multi_logloss: 0.401206	valid_1's multi_logloss: 0.449033
# [195]	valid_0's multi_logloss: 0.400935	valid_1's multi_logloss: 0.44903
# [196]	valid_0's multi_logloss: 0.400675	valid_1's multi_logloss: 0.449005
# [197]	valid_0's multi_logloss: 0.400396	valid_1's multi_logloss: 0.448956
# [198]	valid_0's multi_logloss: 0.400125	valid_1's multi_logloss: 0.448959
# [199]	valid_0's multi_logloss: 0.399858	valid_1's multi_logloss: 0.448949
# [200]	valid_0's multi_logloss: 0.399586	valid_1's multi_logloss: 0.448954
# 0.8418282591084815 0.8184406641776951

# %%
probs_tr = model.predict_proba(x_train_1)
probs_val = model.predict_proba(x_val)

# %%
np.save("Preds/LGB_val", probs_val)
np.save("Preds/LGB_tr", probs_tr)

probs_test = model.predict_proba(x_test)
np.save("Preds/LGB_test", probs_test)
