# %%
import numpy as np
import pandas as pd
# library for splitting training-testing
from sklearn.model_selection import train_test_split
# library for classification
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA

from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import StandardScaler
from sklearn import pipeline
import xgboost as XGB

from hyperopt import tpe,hp,Trials
from hyperopt.fmin import fmin
import warnings
# Out:
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
x_train = pd.read_feather("Data/x_train__IterativeImputer_genFeats.ftr")
x_test = pd.read_feather("Data/x_test__IterativeImputer_genFeats.ftr")

y_train = pd.read_csv("Data/train_y.csv")
y_test = pd.read_csv("Data/Sample_Output.csv", names = ['ID', 'Target'], header=None)

# %%
x_train_1, x_val, y_train_1, y_val = train_test_split(x_train, y_train, test_size=0.15, random_state=59, stratify=y_train)

# %%
def objective(space):
    warnings.filterwarnings(action='ignore', category=DeprecationWarning)
    model = XGB.XGBClassifier(n_estimators = space['n_estimators'],
                            max_depth = int(space['max_depth']),
                            learning_rate = space['learning_rate'],
                            gamma = space['gamma'],
                            min_child_weight = space['min_child_weight'],
                            subsample = space['subsample'],
                            colsample_bytree = space['colsample_bytree'],
                            verbosity=1,
#                             early_stopping_rounds=10,
                            eval_metric=['mlogloss', 'auc'],
                            n_jobs=8)
    
    model.fit(x_train_1, 
              y_train_1.values.reshape(-1), 
              eval_set=[(x_train_1, y_train_1.values.reshape(-1)), (x_val, y_val.values.reshape(-1))], 
              verbose=1,
              early_stopping_rounds=10,)
    
    preds_tr = model.predict(x_train_1,)
    preds_val = model.predict(x_val)
    val_score = accuracy_score(y_val, preds_val)
    tr_score = accuracy_score(y_train_1, preds_tr)
    print(tr_score, val_score, space)
    return -1.0*val_score

def optimize(trial):
    space = {
    'max_depth' : hp.choice('max_depth', range(5, 16, 1)),
    'learning_rate' : hp.quniform('learning_rate', 0.01, 0.5, 0.01),
    'n_estimators' : hp.choice('n_estimators', range(20, 100, 5)),
    'gamma' : hp.quniform('gamma', 0, 0.50, 0.01),
    'min_child_weight' : hp.quniform('min_child_weight', 1, 10, 1),
    'subsample' : hp.quniform('subsample', 0.1, 1, 0.01),
    'colsample_bytree' : hp.quniform('colsample_bytree', 0.1, 1.0, 0.01)}
    best=fmin(fn=objective,space=space,algo=tpe.suggest,trials=trial,max_evals=20,rstate=np.random.default_rng(59))
    return best

trial=Trials()
best=optimize(trial)
# Out:
#   0%|                                                                   | 0/20 [00:00<?, ?trial/s, best loss=?]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.14156	validation_0-auc:0.92701	validation_1-mlogloss:1.14372	validation_1-auc:0.92225
# [1]	validation_0-mlogloss:0.98147	validation_0-auc:0.93502	validation_1-mlogloss:0.98607	validation_1-auc:0.92927
# [2]	validation_0-mlogloss:0.86491	validation_0-auc:0.93877	validation_1-mlogloss:0.87144	validation_1-auc:0.93282
# [3]	validation_0-mlogloss:0.77690	validation_0-auc:0.94105	validation_1-mlogloss:0.78562	validation_1-auc:0.93461
# [4]	validation_0-mlogloss:0.70906	validation_0-auc:0.94248	validation_1-mlogloss:0.71975	validation_1-auc:0.93563
# [5]	validation_0-mlogloss:0.65556	validation_0-auc:0.94381	validation_1-mlogloss:0.66863	validation_1-auc:0.93654
# [6]	validation_0-mlogloss:0.61347	validation_0-auc:0.94476	validation_1-mlogloss:0.62845	validation_1-auc:0.93729
# [7]	validation_0-mlogloss:0.57933	validation_0-auc:0.94556	validation_1-mlogloss:0.59642	validation_1-auc:0.93771
# [8]	validation_0-mlogloss:0.55199	validation_0-auc:0.94624	validation_1-mlogloss:0.57079	validation_1-auc:0.93810
# [9]	validation_0-mlogloss:0.52986	validation_0-auc:0.94700	validation_1-mlogloss:0.55049	validation_1-auc:0.93851
# [10]	validation_0-mlogloss:0.51122	validation_0-auc:0.94784	validation_1-mlogloss:0.53418	validation_1-auc:0.93888
# [11]	validation_0-mlogloss:0.49604	validation_0-auc:0.94845	validation_1-mlogloss:0.52102	validation_1-auc:0.93911
# [12]	validation_0-mlogloss:0.48344	validation_0-auc:0.94902	validation_1-mlogloss:0.51035	validation_1-auc:0.93939
# [13]	validation_0-mlogloss:0.47305	validation_0-auc:0.94953	validation_1-mlogloss:0.50144	validation_1-auc:0.93971
# [14]	validation_0-mlogloss:0.46437	validation_0-auc:0.95005	validation_1-mlogloss:0.49458	validation_1-auc:0.93992
# [15]	validation_0-mlogloss:0.45697	validation_0-auc:0.95057	validation_1-mlogloss:0.48892	validation_1-auc:0.94016
# [16]	validation_0-mlogloss:0.45054	validation_0-auc:0.95108	validation_1-mlogloss:0.48416	validation_1-auc:0.94037
# [17]	validation_0-mlogloss:0.44510	validation_0-auc:0.95158	validation_1-mlogloss:0.48038	validation_1-auc:0.94057
# [18]	validation_0-mlogloss:0.44018	validation_0-auc:0.95206	validation_1-mlogloss:0.47701	validation_1-auc:0.94080
# [19]	validation_0-mlogloss:0.43590	validation_0-auc:0.95258	validation_1-mlogloss:0.47489	validation_1-auc:0.94085
# [20]	validation_0-mlogloss:0.43237	validation_0-auc:0.95301	validation_1-mlogloss:0.47274	validation_1-auc:0.94107
# [21]	validation_0-mlogloss:0.42900	validation_0-auc:0.95342	validation_1-mlogloss:0.47116	validation_1-auc:0.94115
# [22]	validation_0-mlogloss:0.42602	validation_0-auc:0.95382	validation_1-mlogloss:0.46984	validation_1-auc:0.94127
# [23]	validation_0-mlogloss:0.42343	validation_0-auc:0.95426	validation_1-mlogloss:0.46898	validation_1-auc:0.94135
# [24]	validation_0-mlogloss:0.42116	validation_0-auc:0.95462	validation_1-mlogloss:0.46804	validation_1-auc:0.94146
# [25]	validation_0-mlogloss:0.41876	validation_0-auc:0.95505	validation_1-mlogloss:0.46720	validation_1-auc:0.94155
# [26]	validation_0-mlogloss:0.41667	validation_0-auc:0.95538	validation_1-mlogloss:0.46661	validation_1-auc:0.94162
# [27]	validation_0-mlogloss:0.41444	validation_0-auc:0.95582	validation_1-mlogloss:0.46600	validation_1-auc:0.94174
# [28]	validation_0-mlogloss:0.41249	validation_0-auc:0.95621	validation_1-mlogloss:0.46569	validation_1-auc:0.94181
# [29]	validation_0-mlogloss:0.41070	validation_0-auc:0.95653	validation_1-mlogloss:0.46538	validation_1-auc:0.94182
# [30]	validation_0-mlogloss:0.40904	validation_0-auc:0.95687	validation_1-mlogloss:0.46514	validation_1-auc:0.94188
# [31]	validation_0-mlogloss:0.40741	validation_0-auc:0.95719	validation_1-mlogloss:0.46474	validation_1-auc:0.94195
# [32]	validation_0-mlogloss:0.40562	validation_0-auc:0.95758	validation_1-mlogloss:0.46462	validation_1-auc:0.94198
# [33]	validation_0-mlogloss:0.40395	validation_0-auc:0.95794	validation_1-mlogloss:0.46456	validation_1-auc:0.94197
# [34]	validation_0-mlogloss:0.40223	validation_0-auc:0.95831	validation_1-mlogloss:0.46454	validation_1-auc:0.94198
# 0.8396004881100093
# 0.8126443627700219
# {'colsample_bytree': 0.53, 'gamma': 0.16, 'learning_rate': 0.2, 'max_depth': 9, 'min_child_weight': 2.0, 'n_estimators': 35, 'subsample': 0.21}
#   5%|█▊                                   | 1/20 [05:31<1:44:51, 331.13s/trial, best loss: -0.8126443627700219]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.00827	validation_0-auc:0.92127	validation_1-mlogloss:1.00945	validation_1-auc:0.91929
# [1]	validation_0-mlogloss:0.82091	validation_0-auc:0.93176	validation_1-mlogloss:0.82274	validation_1-auc:0.93011
# [2]	validation_0-mlogloss:0.70557	validation_0-auc:0.93543	validation_1-mlogloss:0.70841	validation_1-auc:0.93362
# [3]	validation_0-mlogloss:0.62870	validation_0-auc:0.93767	validation_1-mlogloss:0.63258	validation_1-auc:0.93555
# [4]	validation_0-mlogloss:0.57803	validation_0-auc:0.93887	validation_1-mlogloss:0.58324	validation_1-auc:0.93636
# [5]	validation_0-mlogloss:0.54307	validation_0-auc:0.93983	validation_1-mlogloss:0.54923	validation_1-auc:0.93712
# [6]	validation_0-mlogloss:0.51869	validation_0-auc:0.94071	validation_1-mlogloss:0.52606	validation_1-auc:0.93767
# [7]	validation_0-mlogloss:0.50071	validation_0-auc:0.94158	validation_1-mlogloss:0.50913	validation_1-auc:0.93829
# [8]	validation_0-mlogloss:0.48793	validation_0-auc:0.94218	validation_1-mlogloss:0.49750	validation_1-auc:0.93863
# [9]	validation_0-mlogloss:0.47878	validation_0-auc:0.94276	validation_1-mlogloss:0.48952	validation_1-auc:0.93893
# [10]	validation_0-mlogloss:0.47091	validation_0-auc:0.94366	validation_1-mlogloss:0.48291	validation_1-auc:0.93957
# [11]	validation_0-mlogloss:0.46501	validation_0-auc:0.94430	validation_1-mlogloss:0.47792	validation_1-auc:0.94003
# [12]	validation_0-mlogloss:0.45997	validation_0-auc:0.94499	validation_1-mlogloss:0.47398	validation_1-auc:0.94046
# [13]	validation_0-mlogloss:0.45601	validation_0-auc:0.94566	validation_1-mlogloss:0.47118	validation_1-auc:0.94080
# [14]	validation_0-mlogloss:0.45267	validation_0-auc:0.94628	validation_1-mlogloss:0.46925	validation_1-auc:0.94104
# [15]	validation_0-mlogloss:0.44938	validation_0-auc:0.94690	validation_1-mlogloss:0.46724	validation_1-auc:0.94134
# [16]	validation_0-mlogloss:0.44643	validation_0-auc:0.94747	validation_1-mlogloss:0.46565	validation_1-auc:0.94161
# [17]	validation_0-mlogloss:0.44427	validation_0-auc:0.94795	validation_1-mlogloss:0.46458	validation_1-auc:0.94184
# [18]	validation_0-mlogloss:0.44207	validation_0-auc:0.94840	validation_1-mlogloss:0.46354	validation_1-auc:0.94202
# [19]	validation_0-mlogloss:0.43998	validation_0-auc:0.94890	validation_1-mlogloss:0.46293	validation_1-auc:0.94212
# [20]	validation_0-mlogloss:0.43799	validation_0-auc:0.94939	validation_1-mlogloss:0.46231	validation_1-auc:0.94224
# [21]	validation_0-mlogloss:0.43606	validation_0-auc:0.94975	validation_1-mlogloss:0.46150	validation_1-auc:0.94238
# [22]	validation_0-mlogloss:0.43468	validation_0-auc:0.95011	validation_1-mlogloss:0.46117	validation_1-auc:0.94247
# [23]	validation_0-mlogloss:0.43325	validation_0-auc:0.95047	validation_1-mlogloss:0.46086	validation_1-auc:0.94254
# [24]	validation_0-mlogloss:0.43152	validation_0-auc:0.95089	validation_1-mlogloss:0.46044	validation_1-auc:0.94267
# [25]	validation_0-mlogloss:0.43000	validation_0-auc:0.95126	validation_1-mlogloss:0.46016	validation_1-auc:0.94273
# [26]	validation_0-mlogloss:0.42840	validation_0-auc:0.95163	validation_1-mlogloss:0.45959	validation_1-auc:0.94288
# [27]	validation_0-mlogloss:0.42718	validation_0-auc:0.95194	validation_1-mlogloss:0.45944	validation_1-auc:0.94292
# [28]	validation_0-mlogloss:0.42597	validation_0-auc:0.95223	validation_1-mlogloss:0.45914	validation_1-auc:0.94303
# [29]	validation_0-mlogloss:0.42464	validation_0-auc:0.95254	validation_1-mlogloss:0.45897	validation_1-auc:0.94309
# [30]	validation_0-mlogloss:0.42321	validation_0-auc:0.95287	validation_1-mlogloss:0.45891	validation_1-auc:0.94310
# [31]	validation_0-mlogloss:0.42218	validation_0-auc:0.95311	validation_1-mlogloss:0.45878	validation_1-auc:0.94313
# [32]	validation_0-mlogloss:0.42099	validation_0-auc:0.95340	validation_1-mlogloss:0.45882	validation_1-auc:0.94313
# [33]	validation_0-mlogloss:0.41995	validation_0-auc:0.95368	validation_1-mlogloss:0.45871	validation_1-auc:0.94318
# [34]	validation_0-mlogloss:0.41881	validation_0-auc:0.95393	validation_1-mlogloss:0.45859	validation_1-auc:0.94322
# [35]	validation_0-mlogloss:0.41789	validation_0-auc:0.95417	validation_1-mlogloss:0.45859	validation_1-auc:0.94324
# [36]	validation_0-mlogloss:0.41674	validation_0-auc:0.95445	validation_1-mlogloss:0.45859	validation_1-auc:0.94326
# [37]	validation_0-mlogloss:0.41565	validation_0-auc:0.95472	validation_1-mlogloss:0.45879	validation_1-auc:0.94323
# [38]	validation_0-mlogloss:0.41445	validation_0-auc:0.95500	validation_1-mlogloss:0.45887	validation_1-auc:0.94323
# [39]	validation_0-mlogloss:0.41337	validation_0-auc:0.95528	validation_1-mlogloss:0.45880	validation_1-auc:0.94327
# 0.8356525395051221
# 0.8131237561195287
# {'colsample_bytree': 0.2, 'gamma': 0.3, 'learning_rate': 0.34, 'max_depth': 7, 'min_child_weight': 7.0, 'n_estimators': 40, 'subsample': 0.46}
#  10%|███▋                                 | 2/20 [13:00<2:00:17, 400.95s/trial, best loss: -0.8131237561195287]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.33460	validation_0-auc:0.93002	validation_1-mlogloss:1.33462	validation_1-auc:0.92751
# [1]	validation_0-mlogloss:1.28759	validation_0-auc:0.93491	validation_1-mlogloss:1.28761	validation_1-auc:0.93231
# [2]	validation_0-mlogloss:1.24348	validation_0-auc:0.93617	validation_1-mlogloss:1.24375	validation_1-auc:0.93348
# [3]	validation_0-mlogloss:1.20252	validation_0-auc:0.93683	validation_1-mlogloss:1.20307	validation_1-auc:0.93415
# [4]	validation_0-mlogloss:1.16445	validation_0-auc:0.93718	validation_1-mlogloss:1.16523	validation_1-auc:0.93447
# [5]	validation_0-mlogloss:1.12914	validation_0-auc:0.93732	validation_1-mlogloss:1.12993	validation_1-auc:0.93464
# [6]	validation_0-mlogloss:1.09595	validation_0-auc:0.93750	validation_1-mlogloss:1.09693	validation_1-auc:0.93486
# [7]	validation_0-mlogloss:1.06502	validation_0-auc:0.93769	validation_1-mlogloss:1.06596	validation_1-auc:0.93510
# [8]	validation_0-mlogloss:1.03585	validation_0-auc:0.93797	validation_1-mlogloss:1.03685	validation_1-auc:0.93537
# [9]	validation_0-mlogloss:1.00819	validation_0-auc:0.93817	validation_1-mlogloss:1.00956	validation_1-auc:0.93558
# [10]	validation_0-mlogloss:0.98233	validation_0-auc:0.93831	validation_1-mlogloss:0.98385	validation_1-auc:0.93568
# [11]	validation_0-mlogloss:0.95783	validation_0-auc:0.93851	validation_1-mlogloss:0.95951	validation_1-auc:0.93584
# [12]	validation_0-mlogloss:0.93474	validation_0-auc:0.93866	validation_1-mlogloss:0.93651	validation_1-auc:0.93602
# [13]	validation_0-mlogloss:0.91286	validation_0-auc:0.93883	validation_1-mlogloss:0.91481	validation_1-auc:0.93615
# [14]	validation_0-mlogloss:0.89222	validation_0-auc:0.93901	validation_1-mlogloss:0.89425	validation_1-auc:0.93630
# [15]	validation_0-mlogloss:0.87260	validation_0-auc:0.93918	validation_1-mlogloss:0.87470	validation_1-auc:0.93644
# [16]	validation_0-mlogloss:0.85400	validation_0-auc:0.93930	validation_1-mlogloss:0.85623	validation_1-auc:0.93656
# [17]	validation_0-mlogloss:0.83614	validation_0-auc:0.93946	validation_1-mlogloss:0.83865	validation_1-auc:0.93670
# [18]	validation_0-mlogloss:0.81943	validation_0-auc:0.93960	validation_1-mlogloss:0.82199	validation_1-auc:0.93678
# [19]	validation_0-mlogloss:0.80342	validation_0-auc:0.93982	validation_1-mlogloss:0.80617	validation_1-auc:0.93694
# [20]	validation_0-mlogloss:0.78809	validation_0-auc:0.93995	validation_1-mlogloss:0.79111	validation_1-auc:0.93704
# [21]	validation_0-mlogloss:0.77363	validation_0-auc:0.94006	validation_1-mlogloss:0.77676	validation_1-auc:0.93713
# [22]	validation_0-mlogloss:0.75982	validation_0-auc:0.94018	validation_1-mlogloss:0.76308	validation_1-auc:0.93721
# [23]	validation_0-mlogloss:0.74663	validation_0-auc:0.94032	validation_1-mlogloss:0.75009	validation_1-auc:0.93731
# [24]	validation_0-mlogloss:0.73416	validation_0-auc:0.94044	validation_1-mlogloss:0.73773	validation_1-auc:0.93739
# [25]	validation_0-mlogloss:0.72216	validation_0-auc:0.94055	validation_1-mlogloss:0.72594	validation_1-auc:0.93747
# [26]	validation_0-mlogloss:0.71071	validation_0-auc:0.94066	validation_1-mlogloss:0.71468	validation_1-auc:0.93755
# [27]	validation_0-mlogloss:0.69982	validation_0-auc:0.94076	validation_1-mlogloss:0.70396	validation_1-auc:0.93761
# [28]	validation_0-mlogloss:0.68942	validation_0-auc:0.94089	validation_1-mlogloss:0.69374	validation_1-auc:0.93767
# [29]	validation_0-mlogloss:0.67949	validation_0-auc:0.94102	validation_1-mlogloss:0.68393	validation_1-auc:0.93775
# [30]	validation_0-mlogloss:0.67000	validation_0-auc:0.94113	validation_1-mlogloss:0.67460	validation_1-auc:0.93783
# [31]	validation_0-mlogloss:0.66085	validation_0-auc:0.94125	validation_1-mlogloss:0.66565	validation_1-auc:0.93792
# [32]	validation_0-mlogloss:0.65210	validation_0-auc:0.94136	validation_1-mlogloss:0.65711	validation_1-auc:0.93800
# [33]	validation_0-mlogloss:0.64377	validation_0-auc:0.94151	validation_1-mlogloss:0.64895	validation_1-auc:0.93811
# [34]	validation_0-mlogloss:0.63579	validation_0-auc:0.94161	validation_1-mlogloss:0.64118	validation_1-auc:0.93817
# [35]	validation_0-mlogloss:0.62825	validation_0-auc:0.94172	validation_1-mlogloss:0.63372	validation_1-auc:0.93822
# [36]	validation_0-mlogloss:0.62086	validation_0-auc:0.94182	validation_1-mlogloss:0.62660	validation_1-auc:0.93829
# [37]	validation_0-mlogloss:0.61393	validation_0-auc:0.94195	validation_1-mlogloss:0.61981	validation_1-auc:0.93840
# [38]	validation_0-mlogloss:0.60721	validation_0-auc:0.94207	validation_1-mlogloss:0.61327	validation_1-auc:0.93847
# [39]	validation_0-mlogloss:0.60072	validation_0-auc:0.94218	validation_1-mlogloss:0.60702	validation_1-auc:0.93854
# [40]	validation_0-mlogloss:0.59465	validation_0-auc:0.94230	validation_1-mlogloss:0.60104	validation_1-auc:0.93864
# [41]	validation_0-mlogloss:0.58866	validation_0-auc:0.94240	validation_1-mlogloss:0.59535	validation_1-auc:0.93871
# [42]	validation_0-mlogloss:0.58305	validation_0-auc:0.94253	validation_1-mlogloss:0.58988	validation_1-auc:0.93880
# [43]	validation_0-mlogloss:0.57764	validation_0-auc:0.94264	validation_1-mlogloss:0.58462	validation_1-auc:0.93889
# [44]	validation_0-mlogloss:0.57240	validation_0-auc:0.94275	validation_1-mlogloss:0.57959	validation_1-auc:0.93896
# [45]	validation_0-mlogloss:0.56741	validation_0-auc:0.94285	validation_1-mlogloss:0.57476	validation_1-auc:0.93904
# [46]	validation_0-mlogloss:0.56268	validation_0-auc:0.94294	validation_1-mlogloss:0.57016	validation_1-auc:0.93909
# [47]	validation_0-mlogloss:0.55804	validation_0-auc:0.94307	validation_1-mlogloss:0.56574	validation_1-auc:0.93918
# [48]	validation_0-mlogloss:0.55363	validation_0-auc:0.94318	validation_1-mlogloss:0.56154	validation_1-auc:0.93924
# [49]	validation_0-mlogloss:0.54941	validation_0-auc:0.94328	validation_1-mlogloss:0.55747	validation_1-auc:0.93932
# [50]	validation_0-mlogloss:0.54534	validation_0-auc:0.94337	validation_1-mlogloss:0.55360	validation_1-auc:0.93937
# [51]	validation_0-mlogloss:0.54143	validation_0-auc:0.94348	validation_1-mlogloss:0.54986	validation_1-auc:0.93945
# [52]	validation_0-mlogloss:0.53769	validation_0-auc:0.94359	validation_1-mlogloss:0.54627	validation_1-auc:0.93951
# [53]	validation_0-mlogloss:0.53413	validation_0-auc:0.94370	validation_1-mlogloss:0.54285	validation_1-auc:0.93959
# [54]	validation_0-mlogloss:0.53062	validation_0-auc:0.94379	validation_1-mlogloss:0.53956	validation_1-auc:0.93964
# [55]	validation_0-mlogloss:0.52733	validation_0-auc:0.94388	validation_1-mlogloss:0.53641	validation_1-auc:0.93969
# [56]	validation_0-mlogloss:0.52416	validation_0-auc:0.94398	validation_1-mlogloss:0.53341	validation_1-auc:0.93974
# [57]	validation_0-mlogloss:0.52101	validation_0-auc:0.94407	validation_1-mlogloss:0.53050	validation_1-auc:0.93980
# [58]	validation_0-mlogloss:0.51802	validation_0-auc:0.94416	validation_1-mlogloss:0.52771	validation_1-auc:0.93985
# [59]	validation_0-mlogloss:0.51516	validation_0-auc:0.94426	validation_1-mlogloss:0.52504	validation_1-auc:0.93991
# [60]	validation_0-mlogloss:0.51241	validation_0-auc:0.94437	validation_1-mlogloss:0.52247	validation_1-auc:0.93998
# [61]	validation_0-mlogloss:0.50980	validation_0-auc:0.94444	validation_1-mlogloss:0.52000	validation_1-auc:0.94002
# [62]	validation_0-mlogloss:0.50725	validation_0-auc:0.94454	validation_1-mlogloss:0.51764	validation_1-auc:0.94007
# [63]	validation_0-mlogloss:0.50483	validation_0-auc:0.94463	validation_1-mlogloss:0.51539	validation_1-auc:0.94012
# [64]	validation_0-mlogloss:0.50243	validation_0-auc:0.94473	validation_1-mlogloss:0.51319	validation_1-auc:0.94019
# [65]	validation_0-mlogloss:0.50016	validation_0-auc:0.94483	validation_1-mlogloss:0.51108	validation_1-auc:0.94025
# [66]	validation_0-mlogloss:0.49800	validation_0-auc:0.94492	validation_1-mlogloss:0.50910	validation_1-auc:0.94031
# [67]	validation_0-mlogloss:0.49587	validation_0-auc:0.94503	validation_1-mlogloss:0.50717	validation_1-auc:0.94036
# [68]	validation_0-mlogloss:0.49383	validation_0-auc:0.94513	validation_1-mlogloss:0.50531	validation_1-auc:0.94042
# [69]	validation_0-mlogloss:0.49192	validation_0-auc:0.94520	validation_1-mlogloss:0.50352	validation_1-auc:0.94047
# 0.8167331494375455
# 0.8136176765402328
# {'colsample_bytree': 0.93, 'gamma': 0.15, 'learning_rate': 0.04, 'max_depth': 7, 'min_child_weight': 5.0, 'n_estimators': 70, 'subsample': 0.72}
#  15%|█████▌                               | 3/20 [35:55<3:59:35, 845.64s/trial, best loss: -0.8136176765402328]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:0.88931	validation_0-auc:0.92453	validation_1-mlogloss:0.88887	validation_1-auc:0.92435
# [1]	validation_0-mlogloss:0.70803	validation_0-auc:0.93156	validation_1-mlogloss:0.70798	validation_1-auc:0.93095
# [2]	validation_0-mlogloss:0.61153	validation_0-auc:0.93385	validation_1-mlogloss:0.61175	validation_1-auc:0.93330
# [3]	validation_0-mlogloss:0.55594	validation_0-auc:0.93528	validation_1-mlogloss:0.55642	validation_1-auc:0.93471
# [4]	validation_0-mlogloss:0.52279	validation_0-auc:0.93651	validation_1-mlogloss:0.52372	validation_1-auc:0.93586
# [5]	validation_0-mlogloss:0.50204	validation_0-auc:0.93779	validation_1-mlogloss:0.50351	validation_1-auc:0.93705
# [6]	validation_0-mlogloss:0.48876	validation_0-auc:0.93863	validation_1-mlogloss:0.49103	validation_1-auc:0.93768
# [7]	validation_0-mlogloss:0.47973	validation_0-auc:0.93943	validation_1-mlogloss:0.48257	validation_1-auc:0.93832
# [8]	validation_0-mlogloss:0.47336	validation_0-auc:0.94029	validation_1-mlogloss:0.47679	validation_1-auc:0.93900
# [9]	validation_0-mlogloss:0.46885	validation_0-auc:0.94102	validation_1-mlogloss:0.47294	validation_1-auc:0.93950
# [10]	validation_0-mlogloss:0.46551	validation_0-auc:0.94160	validation_1-mlogloss:0.47006	validation_1-auc:0.94003
# [11]	validation_0-mlogloss:0.46231	validation_0-auc:0.94247	validation_1-mlogloss:0.46779	validation_1-auc:0.94052
# [12]	validation_0-mlogloss:0.45975	validation_0-auc:0.94310	validation_1-mlogloss:0.46594	validation_1-auc:0.94093
# [13]	validation_0-mlogloss:0.45725	validation_0-auc:0.94375	validation_1-mlogloss:0.46420	validation_1-auc:0.94137
# [14]	validation_0-mlogloss:0.45527	validation_0-auc:0.94432	validation_1-mlogloss:0.46293	validation_1-auc:0.94168
# [15]	validation_0-mlogloss:0.45353	validation_0-auc:0.94481	validation_1-mlogloss:0.46196	validation_1-auc:0.94194
# [16]	validation_0-mlogloss:0.45189	validation_0-auc:0.94522	validation_1-mlogloss:0.46085	validation_1-auc:0.94222
# [17]	validation_0-mlogloss:0.45013	validation_0-auc:0.94568	validation_1-mlogloss:0.45993	validation_1-auc:0.94248
# [18]	validation_0-mlogloss:0.44861	validation_0-auc:0.94610	validation_1-mlogloss:0.45927	validation_1-auc:0.94270
# [19]	validation_0-mlogloss:0.44722	validation_0-auc:0.94645	validation_1-mlogloss:0.45874	validation_1-auc:0.94288
# [20]	validation_0-mlogloss:0.44598	validation_0-auc:0.94677	validation_1-mlogloss:0.45826	validation_1-auc:0.94302
# [21]	validation_0-mlogloss:0.44484	validation_0-auc:0.94708	validation_1-mlogloss:0.45781	validation_1-auc:0.94315
# [22]	validation_0-mlogloss:0.44366	validation_0-auc:0.94741	validation_1-mlogloss:0.45759	validation_1-auc:0.94323
# [23]	validation_0-mlogloss:0.44246	validation_0-auc:0.94775	validation_1-mlogloss:0.45735	validation_1-auc:0.94331
# [24]	validation_0-mlogloss:0.44130	validation_0-auc:0.94805	validation_1-mlogloss:0.45711	validation_1-auc:0.94339
# [25]	validation_0-mlogloss:0.44018	validation_0-auc:0.94835	validation_1-mlogloss:0.45687	validation_1-auc:0.94348
# [26]	validation_0-mlogloss:0.43922	validation_0-auc:0.94860	validation_1-mlogloss:0.45654	validation_1-auc:0.94356
# [27]	validation_0-mlogloss:0.43823	validation_0-auc:0.94886	validation_1-mlogloss:0.45619	validation_1-auc:0.94371
# [28]	validation_0-mlogloss:0.43736	validation_0-auc:0.94910	validation_1-mlogloss:0.45607	validation_1-auc:0.94376
# [29]	validation_0-mlogloss:0.43651	validation_0-auc:0.94934	validation_1-mlogloss:0.45582	validation_1-auc:0.94383
# [30]	validation_0-mlogloss:0.43563	validation_0-auc:0.94959	validation_1-mlogloss:0.45555	validation_1-auc:0.94392
# [31]	validation_0-mlogloss:0.43476	validation_0-auc:0.94982	validation_1-mlogloss:0.45545	validation_1-auc:0.94395
# [32]	validation_0-mlogloss:0.43409	validation_0-auc:0.94998	validation_1-mlogloss:0.45533	validation_1-auc:0.94397
# [33]	validation_0-mlogloss:0.43314	validation_0-auc:0.95023	validation_1-mlogloss:0.45516	validation_1-auc:0.94402
# [34]	validation_0-mlogloss:0.43227	validation_0-auc:0.95044	validation_1-mlogloss:0.45506	validation_1-auc:0.94406
# [35]	validation_0-mlogloss:0.43138	validation_0-auc:0.95070	validation_1-mlogloss:0.45508	validation_1-auc:0.94407
# [36]	validation_0-mlogloss:0.43049	validation_0-auc:0.95093	validation_1-mlogloss:0.45490	validation_1-auc:0.94413
# [37]	validation_0-mlogloss:0.42980	validation_0-auc:0.95109	validation_1-mlogloss:0.45496	validation_1-auc:0.94411
# [38]	validation_0-mlogloss:0.42904	validation_0-auc:0.95129	validation_1-mlogloss:0.45487	validation_1-auc:0.94415
# [39]	validation_0-mlogloss:0.42819	validation_0-auc:0.95150	validation_1-mlogloss:0.45468	validation_1-auc:0.94420
# [40]	validation_0-mlogloss:0.42734	validation_0-auc:0.95171	validation_1-mlogloss:0.45465	validation_1-auc:0.94422
# [41]	validation_0-mlogloss:0.42658	validation_0-auc:0.95189	validation_1-mlogloss:0.45450	validation_1-auc:0.94427
# [42]	validation_0-mlogloss:0.42590	validation_0-auc:0.95205	validation_1-mlogloss:0.45440	validation_1-auc:0.94431
# [43]	validation_0-mlogloss:0.42530	validation_0-auc:0.95220	validation_1-mlogloss:0.45448	validation_1-auc:0.94430
# [44]	validation_0-mlogloss:0.42462	validation_0-auc:0.95236	validation_1-mlogloss:0.45446	validation_1-auc:0.94432
# [45]	validation_0-mlogloss:0.42403	validation_0-auc:0.95251	validation_1-mlogloss:0.45442	validation_1-auc:0.94434
# [46]	validation_0-mlogloss:0.42344	validation_0-auc:0.95265	validation_1-mlogloss:0.45436	validation_1-auc:0.94439
# [47]	validation_0-mlogloss:0.42276	validation_0-auc:0.95282	validation_1-mlogloss:0.45444	validation_1-auc:0.94438
# [48]	validation_0-mlogloss:0.42210	validation_0-auc:0.95300	validation_1-mlogloss:0.45444	validation_1-auc:0.94439
# [49]	validation_0-mlogloss:0.42169	validation_0-auc:0.95311	validation_1-mlogloss:0.45447	validation_1-auc:0.94438
# 0.8297331802007814
# 0.8153609250838938
# {'colsample_bytree': 0.8200000000000001, 'gamma': 0.05, 'learning_rate': 0.47000000000000003, 'max_depth': 5, 'min_child_weight': 6.0, 'n_estimators': 50, 'subsample': 0.7000000000000001}
#  20%|███████▍                             | 4/20 [43:03<3:01:28, 680.54s/trial, best loss: -0.8153609250838938]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.10731	validation_0-auc:0.93721	validation_1-mlogloss:1.11980	validation_1-auc:0.91377
# [1]	validation_0-mlogloss:0.92914	validation_0-auc:0.95014	validation_1-mlogloss:0.95299	validation_1-auc:0.92491
# [2]	validation_0-mlogloss:0.80224	validation_0-auc:0.95566	validation_1-mlogloss:0.83680	validation_1-auc:0.92950
# [3]	validation_0-mlogloss:0.70734	validation_0-auc:0.95915	validation_1-mlogloss:0.75209	validation_1-auc:0.93180
# [4]	validation_0-mlogloss:0.63450	validation_0-auc:0.96169	validation_1-mlogloss:0.68839	validation_1-auc:0.93353
# [5]	validation_0-mlogloss:0.57738	validation_0-auc:0.96369	validation_1-mlogloss:0.63988	validation_1-auc:0.93465
# [6]	validation_0-mlogloss:0.53144	validation_0-auc:0.96547	validation_1-mlogloss:0.60253	validation_1-auc:0.93555
# [7]	validation_0-mlogloss:0.49469	validation_0-auc:0.96700	validation_1-mlogloss:0.57368	validation_1-auc:0.93623
# [8]	validation_0-mlogloss:0.46446	validation_0-auc:0.96840	validation_1-mlogloss:0.55115	validation_1-auc:0.93677
# [9]	validation_0-mlogloss:0.43936	validation_0-auc:0.96979	validation_1-mlogloss:0.53351	validation_1-auc:0.93728
# [10]	validation_0-mlogloss:0.41898	validation_0-auc:0.97092	validation_1-mlogloss:0.51958	validation_1-auc:0.93769
# [11]	validation_0-mlogloss:0.40125	validation_0-auc:0.97213	validation_1-mlogloss:0.50877	validation_1-auc:0.93806
# [12]	validation_0-mlogloss:0.38642	validation_0-auc:0.97322	validation_1-mlogloss:0.50040	validation_1-auc:0.93831
# [13]	validation_0-mlogloss:0.37416	validation_0-auc:0.97408	validation_1-mlogloss:0.49370	validation_1-auc:0.93861
# [14]	validation_0-mlogloss:0.36302	validation_0-auc:0.97514	validation_1-mlogloss:0.48836	validation_1-auc:0.93894
# [15]	validation_0-mlogloss:0.35323	validation_0-auc:0.97604	validation_1-mlogloss:0.48436	validation_1-auc:0.93913
# [16]	validation_0-mlogloss:0.34446	validation_0-auc:0.97691	validation_1-mlogloss:0.48113	validation_1-auc:0.93940
# [17]	validation_0-mlogloss:0.33655	validation_0-auc:0.97778	validation_1-mlogloss:0.47880	validation_1-auc:0.93956
# [18]	validation_0-mlogloss:0.32897	validation_0-auc:0.97867	validation_1-mlogloss:0.47718	validation_1-auc:0.93965
# [19]	validation_0-mlogloss:0.32264	validation_0-auc:0.97941	validation_1-mlogloss:0.47583	validation_1-auc:0.93979
# [20]	validation_0-mlogloss:0.31714	validation_0-auc:0.98008	validation_1-mlogloss:0.47482	validation_1-auc:0.93984
# [21]	validation_0-mlogloss:0.31159	validation_0-auc:0.98075	validation_1-mlogloss:0.47415	validation_1-auc:0.93992
# [22]	validation_0-mlogloss:0.30598	validation_0-auc:0.98147	validation_1-mlogloss:0.47389	validation_1-auc:0.93997
# [23]	validation_0-mlogloss:0.30175	validation_0-auc:0.98204	validation_1-mlogloss:0.47376	validation_1-auc:0.94000
# [24]	validation_0-mlogloss:0.29724	validation_0-auc:0.98264	validation_1-mlogloss:0.47364	validation_1-auc:0.94008
# [25]	validation_0-mlogloss:0.29284	validation_0-auc:0.98320	validation_1-mlogloss:0.47340	validation_1-auc:0.94016
# [26]	validation_0-mlogloss:0.28857	validation_0-auc:0.98380	validation_1-mlogloss:0.47337	validation_1-auc:0.94022
# [27]	validation_0-mlogloss:0.28449	validation_0-auc:0.98441	validation_1-mlogloss:0.47316	validation_1-auc:0.94033
# [28]	validation_0-mlogloss:0.28060	validation_0-auc:0.98494	validation_1-mlogloss:0.47318	validation_1-auc:0.94034
# [29]	validation_0-mlogloss:0.27612	validation_0-auc:0.98555	validation_1-mlogloss:0.47329	validation_1-auc:0.94040
# [30]	validation_0-mlogloss:0.27217	validation_0-auc:0.98614	validation_1-mlogloss:0.47374	validation_1-auc:0.94033
# [31]	validation_0-mlogloss:0.26888	validation_0-auc:0.98659	validation_1-mlogloss:0.47388	validation_1-auc:0.94034
# [32]	validation_0-mlogloss:0.26492	validation_0-auc:0.98715	validation_1-mlogloss:0.47408	validation_1-auc:0.94037
# [33]	validation_0-mlogloss:0.26163	validation_0-auc:0.98760	validation_1-mlogloss:0.47437	validation_1-auc:0.94038
# [34]	validation_0-mlogloss:0.25849	validation_0-auc:0.98804	validation_1-mlogloss:0.47455	validation_1-auc:0.94037
# [35]	validation_0-mlogloss:0.25577	validation_0-auc:0.98841	validation_1-mlogloss:0.47478	validation_1-auc:0.94035
# [36]	validation_0-mlogloss:0.25284	validation_0-auc:0.98881	validation_1-mlogloss:0.47502	validation_1-auc:0.94032
# [37]	validation_0-mlogloss:0.24880	validation_0-auc:0.98931	validation_1-mlogloss:0.47550	validation_1-auc:0.94030
# [38]	validation_0-mlogloss:0.24568	validation_0-auc:0.98970	validation_1-mlogloss:0.47583	validation_1-auc:0.94028
# 0.916231708692665
# 0.8083152955532635
# {'colsample_bytree': 0.99, 'gamma': 0.18, 'learning_rate': 0.22, 'max_depth': 14, 'min_child_weight': 5.0, 'n_estimators': 95, 'subsample': 0.38}
#  25%|████████▊                          | 5/20 [1:01:29<3:28:33, 834.20s/trial, best loss: -0.8153609250838938]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.08052	validation_0-auc:0.92990	validation_1-mlogloss:1.08139	validation_1-auc:0.92800
# [1]	validation_0-mlogloss:0.90455	validation_0-auc:0.93511	validation_1-mlogloss:0.90601	validation_1-auc:0.93316
# [2]	validation_0-mlogloss:0.78524	validation_0-auc:0.93748	validation_1-mlogloss:0.78772	validation_1-auc:0.93520
# [3]	validation_0-mlogloss:0.70126	validation_0-auc:0.93889	validation_1-mlogloss:0.70490	validation_1-auc:0.93632
# [4]	validation_0-mlogloss:0.64087	validation_0-auc:0.93977	validation_1-mlogloss:0.64525	validation_1-auc:0.93710
# [5]	validation_0-mlogloss:0.59585	validation_0-auc:0.94067	validation_1-mlogloss:0.60147	validation_1-auc:0.93773
# [6]	validation_0-mlogloss:0.56182	validation_0-auc:0.94154	validation_1-mlogloss:0.56844	validation_1-auc:0.93839
# [7]	validation_0-mlogloss:0.53615	validation_0-auc:0.94215	validation_1-mlogloss:0.54373	validation_1-auc:0.93877
# [8]	validation_0-mlogloss:0.51643	validation_0-auc:0.94272	validation_1-mlogloss:0.52508	validation_1-auc:0.93912
# [9]	validation_0-mlogloss:0.50116	validation_0-auc:0.94337	validation_1-mlogloss:0.51095	validation_1-auc:0.93952
# [10]	validation_0-mlogloss:0.48911	validation_0-auc:0.94398	validation_1-mlogloss:0.50001	validation_1-auc:0.93993
# [11]	validation_0-mlogloss:0.47936	validation_0-auc:0.94456	validation_1-mlogloss:0.49126	validation_1-auc:0.94029
# [12]	validation_0-mlogloss:0.47154	validation_0-auc:0.94516	validation_1-mlogloss:0.48465	validation_1-auc:0.94056
# [13]	validation_0-mlogloss:0.46527	validation_0-auc:0.94568	validation_1-mlogloss:0.47946	validation_1-auc:0.94088
# [14]	validation_0-mlogloss:0.45985	validation_0-auc:0.94631	validation_1-mlogloss:0.47516	validation_1-auc:0.94128
# [15]	validation_0-mlogloss:0.45523	validation_0-auc:0.94687	validation_1-mlogloss:0.47169	validation_1-auc:0.94152
# [16]	validation_0-mlogloss:0.45143	validation_0-auc:0.94743	validation_1-mlogloss:0.46912	validation_1-auc:0.94174
# [17]	validation_0-mlogloss:0.44827	validation_0-auc:0.94790	validation_1-mlogloss:0.46691	validation_1-auc:0.94198
# [18]	validation_0-mlogloss:0.44551	validation_0-auc:0.94836	validation_1-mlogloss:0.46520	validation_1-auc:0.94217
# [19]	validation_0-mlogloss:0.44293	validation_0-auc:0.94888	validation_1-mlogloss:0.46381	validation_1-auc:0.94232
# [20]	validation_0-mlogloss:0.44072	validation_0-auc:0.94930	validation_1-mlogloss:0.46256	validation_1-auc:0.94255
# [21]	validation_0-mlogloss:0.43846	validation_0-auc:0.94970	validation_1-mlogloss:0.46140	validation_1-auc:0.94271
# [22]	validation_0-mlogloss:0.43655	validation_0-auc:0.95010	validation_1-mlogloss:0.46061	validation_1-auc:0.94281
# [23]	validation_0-mlogloss:0.43455	validation_0-auc:0.95056	validation_1-mlogloss:0.45987	validation_1-auc:0.94296
# [24]	validation_0-mlogloss:0.43280	validation_0-auc:0.95096	validation_1-mlogloss:0.45927	validation_1-auc:0.94309
# [25]	validation_0-mlogloss:0.43090	validation_0-auc:0.95140	validation_1-mlogloss:0.45860	validation_1-auc:0.94323
# [26]	validation_0-mlogloss:0.42919	validation_0-auc:0.95181	validation_1-mlogloss:0.45814	validation_1-auc:0.94333
# [27]	validation_0-mlogloss:0.42762	validation_0-auc:0.95216	validation_1-mlogloss:0.45754	validation_1-auc:0.94348
# [28]	validation_0-mlogloss:0.42619	validation_0-auc:0.95248	validation_1-mlogloss:0.45720	validation_1-auc:0.94356
# [29]	validation_0-mlogloss:0.42457	validation_0-auc:0.95286	validation_1-mlogloss:0.45680	validation_1-auc:0.94367
# [30]	validation_0-mlogloss:0.42319	validation_0-auc:0.95317	validation_1-mlogloss:0.45662	validation_1-auc:0.94367
# [31]	validation_0-mlogloss:0.42199	validation_0-auc:0.95344	validation_1-mlogloss:0.45637	validation_1-auc:0.94372
# [32]	validation_0-mlogloss:0.42046	validation_0-auc:0.95381	validation_1-mlogloss:0.45616	validation_1-auc:0.94375
# [33]	validation_0-mlogloss:0.41887	validation_0-auc:0.95421	validation_1-mlogloss:0.45590	validation_1-auc:0.94382
# [34]	validation_0-mlogloss:0.41766	validation_0-auc:0.95449	validation_1-mlogloss:0.45569	validation_1-auc:0.94387
# [35]	validation_0-mlogloss:0.41663	validation_0-auc:0.95473	validation_1-mlogloss:0.45551	validation_1-auc:0.94390
# [36]	validation_0-mlogloss:0.41552	validation_0-auc:0.95500	validation_1-mlogloss:0.45530	validation_1-auc:0.94398
# [37]	validation_0-mlogloss:0.41424	validation_0-auc:0.95531	validation_1-mlogloss:0.45516	validation_1-auc:0.94404
# [38]	validation_0-mlogloss:0.41293	validation_0-auc:0.95563	validation_1-mlogloss:0.45503	validation_1-auc:0.94407
# [39]	validation_0-mlogloss:0.41165	validation_0-auc:0.95596	validation_1-mlogloss:0.45488	validation_1-auc:0.94412
# [40]	validation_0-mlogloss:0.41045	validation_0-auc:0.95624	validation_1-mlogloss:0.45481	validation_1-auc:0.94415
# [41]	validation_0-mlogloss:0.40920	validation_0-auc:0.95655	validation_1-mlogloss:0.45467	validation_1-auc:0.94420
# [42]	validation_0-mlogloss:0.40806	validation_0-auc:0.95683	validation_1-mlogloss:0.45450	validation_1-auc:0.94425
# [43]	validation_0-mlogloss:0.40704	validation_0-auc:0.95708	validation_1-mlogloss:0.45441	validation_1-auc:0.94430
# [44]	validation_0-mlogloss:0.40592	validation_0-auc:0.95735	validation_1-mlogloss:0.45435	validation_1-auc:0.94432
# [45]	validation_0-mlogloss:0.40479	validation_0-auc:0.95763	validation_1-mlogloss:0.45424	validation_1-auc:0.94437
# [46]	validation_0-mlogloss:0.40373	validation_0-auc:0.95788	validation_1-mlogloss:0.45420	validation_1-auc:0.94436
# [47]	validation_0-mlogloss:0.40258	validation_0-auc:0.95817	validation_1-mlogloss:0.45409	validation_1-auc:0.94440
# [48]	validation_0-mlogloss:0.40167	validation_0-auc:0.95839	validation_1-mlogloss:0.45396	validation_1-auc:0.94444
# [49]	validation_0-mlogloss:0.40062	validation_0-auc:0.95865	validation_1-mlogloss:0.45387	validation_1-auc:0.94447
# [50]	validation_0-mlogloss:0.39969	validation_0-auc:0.95886	validation_1-mlogloss:0.45377	validation_1-auc:0.94450
# [51]	validation_0-mlogloss:0.39854	validation_0-auc:0.95915	validation_1-mlogloss:0.45373	validation_1-auc:0.94452
# [52]	validation_0-mlogloss:0.39767	validation_0-auc:0.95938	validation_1-mlogloss:0.45368	validation_1-auc:0.94454
# [53]	validation_0-mlogloss:0.39687	validation_0-auc:0.95956	validation_1-mlogloss:0.45369	validation_1-auc:0.94456
# [54]	validation_0-mlogloss:0.39598	validation_0-auc:0.95976	validation_1-mlogloss:0.45371	validation_1-auc:0.94455
# [55]	validation_0-mlogloss:0.39497	validation_0-auc:0.96000	validation_1-mlogloss:0.45371	validation_1-auc:0.94454
# [56]	validation_0-mlogloss:0.39401	validation_0-auc:0.96022	validation_1-mlogloss:0.45377	validation_1-auc:0.94455
# [57]	validation_0-mlogloss:0.39320	validation_0-auc:0.96042	validation_1-mlogloss:0.45376	validation_1-auc:0.94456
# [58]	validation_0-mlogloss:0.39216	validation_0-auc:0.96066	validation_1-mlogloss:0.45372	validation_1-auc:0.94458
# [59]	validation_0-mlogloss:0.39122	validation_0-auc:0.96089	validation_1-mlogloss:0.45368	validation_1-auc:0.94460
# [60]	validation_0-mlogloss:0.39064	validation_0-auc:0.96103	validation_1-mlogloss:0.45364	validation_1-auc:0.94462
# [61]	validation_0-mlogloss:0.38985	validation_0-auc:0.96123	validation_1-mlogloss:0.45367	validation_1-auc:0.94463
# [62]	validation_0-mlogloss:0.38900	validation_0-auc:0.96144	validation_1-mlogloss:0.45366	validation_1-auc:0.94462
# [63]	validation_0-mlogloss:0.38808	validation_0-auc:0.96168	validation_1-mlogloss:0.45369	validation_1-auc:0.94461
# [64]	validation_0-mlogloss:0.38722	validation_0-auc:0.96191	validation_1-mlogloss:0.45372	validation_1-auc:0.94461
# [65]	validation_0-mlogloss:0.38654	validation_0-auc:0.96208	validation_1-mlogloss:0.45373	validation_1-auc:0.94460
# [66]	validation_0-mlogloss:0.38600	validation_0-auc:0.96219	validation_1-mlogloss:0.45367	validation_1-auc:0.94463
# [67]	validation_0-mlogloss:0.38505	validation_0-auc:0.96242	validation_1-mlogloss:0.45363	validation_1-auc:0.94464
# [68]	validation_0-mlogloss:0.38414	validation_0-auc:0.96262	validation_1-mlogloss:0.45367	validation_1-auc:0.94466
# [69]	validation_0-mlogloss:0.38335	validation_0-auc:0.96280	validation_1-mlogloss:0.45366	validation_1-auc:0.94467
# [70]	validation_0-mlogloss:0.38246	validation_0-auc:0.96303	validation_1-mlogloss:0.45361	validation_1-auc:0.94468
# [71]	validation_0-mlogloss:0.38163	validation_0-auc:0.96321	validation_1-mlogloss:0.45362	validation_1-auc:0.94469
# [72]	validation_0-mlogloss:0.38107	validation_0-auc:0.96334	validation_1-mlogloss:0.45356	validation_1-auc:0.94471
# [73]	validation_0-mlogloss:0.38027	validation_0-auc:0.96353	validation_1-mlogloss:0.45362	validation_1-auc:0.94470
# [74]	validation_0-mlogloss:0.37959	validation_0-auc:0.96369	validation_1-mlogloss:0.45361	validation_1-auc:0.94471
# [75]	validation_0-mlogloss:0.37867	validation_0-auc:0.96388	validation_1-mlogloss:0.45355	validation_1-auc:0.94473
# [76]	validation_0-mlogloss:0.37761	validation_0-auc:0.96415	validation_1-mlogloss:0.45358	validation_1-auc:0.94472
# [77]	validation_0-mlogloss:0.37674	validation_0-auc:0.96434	validation_1-mlogloss:0.45361	validation_1-auc:0.94471
# [78]	validation_0-mlogloss:0.37585	validation_0-auc:0.96454	validation_1-mlogloss:0.45356	validation_1-auc:0.94473
# [79]	validation_0-mlogloss:0.37534	validation_0-auc:0.96465	validation_1-mlogloss:0.45361	validation_1-auc:0.94473
# [80]	validation_0-mlogloss:0.37470	validation_0-auc:0.96481	validation_1-mlogloss:0.45367	validation_1-auc:0.94471
# [81]	validation_0-mlogloss:0.37381	validation_0-auc:0.96501	validation_1-mlogloss:0.45369	validation_1-auc:0.94471
# [82]	validation_0-mlogloss:0.37299	validation_0-auc:0.96520	validation_1-mlogloss:0.45384	validation_1-auc:0.94468
# [83]	validation_0-mlogloss:0.37222	validation_0-auc:0.96537	validation_1-mlogloss:0.45386	validation_1-auc:0.94467
# [84]	validation_0-mlogloss:0.37128	validation_0-auc:0.96560	validation_1-mlogloss:0.45393	validation_1-auc:0.94465
# [85]	validation_0-mlogloss:0.37065	validation_0-auc:0.96576	validation_1-mlogloss:0.45407	validation_1-auc:0.94461
# [86]	validation_0-mlogloss:0.36992	validation_0-auc:0.96592	validation_1-mlogloss:0.45417	validation_1-auc:0.94458
# [87]	validation_0-mlogloss:0.36917	validation_0-auc:0.96608	validation_1-mlogloss:0.45425	validation_1-auc:0.94458
# [88]	validation_0-mlogloss:0.36835	validation_0-auc:0.96626	validation_1-mlogloss:0.45420	validation_1-auc:0.94460
# 0.8554717542222541
# 0.8153173438703023
# {'colsample_bytree': 0.39, 'gamma': 0.47000000000000003, 'learning_rate': 0.26, 'max_depth': 7, 'min_child_weight': 5.0, 'n_estimators': 90, 'subsample': 0.6900000000000001}
#  30%|██████████▌                        | 6/20 [1:10:30<2:51:21, 734.39s/trial, best loss: -0.8153609250838938]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.24269	validation_0-auc:0.93775	validation_1-mlogloss:1.24636	validation_1-auc:0.92360
# [1]	validation_0-mlogloss:1.12887	validation_0-auc:0.94683	validation_1-mlogloss:1.13627	validation_1-auc:0.93120
# [2]	validation_0-mlogloss:1.03471	validation_0-auc:0.95062	validation_1-mlogloss:1.04582	validation_1-auc:0.93404
# [3]	validation_0-mlogloss:0.95539	validation_0-auc:0.95263	validation_1-mlogloss:0.97006	validation_1-auc:0.93570
# [4]	validation_0-mlogloss:0.88813	validation_0-auc:0.95386	validation_1-mlogloss:0.90589	validation_1-auc:0.93677
# [5]	validation_0-mlogloss:0.82980	validation_0-auc:0.95528	validation_1-mlogloss:0.85107	validation_1-auc:0.93761
# [6]	validation_0-mlogloss:0.77939	validation_0-auc:0.95626	validation_1-mlogloss:0.80398	validation_1-auc:0.93803
# [7]	validation_0-mlogloss:0.73538	validation_0-auc:0.95692	validation_1-mlogloss:0.76294	validation_1-auc:0.93845
# [8]	validation_0-mlogloss:0.69665	validation_0-auc:0.95775	validation_1-mlogloss:0.72737	validation_1-auc:0.93876
# [9]	validation_0-mlogloss:0.66248	validation_0-auc:0.95844	validation_1-mlogloss:0.69622	validation_1-auc:0.93907
# [10]	validation_0-mlogloss:0.63232	validation_0-auc:0.95906	validation_1-mlogloss:0.66896	validation_1-auc:0.93931
# [11]	validation_0-mlogloss:0.60546	validation_0-auc:0.95968	validation_1-mlogloss:0.64494	validation_1-auc:0.93958
# [12]	validation_0-mlogloss:0.58140	validation_0-auc:0.96036	validation_1-mlogloss:0.62379	validation_1-auc:0.93980
# [13]	validation_0-mlogloss:0.56021	validation_0-auc:0.96081	validation_1-mlogloss:0.60505	validation_1-auc:0.94003
# [14]	validation_0-mlogloss:0.54096	validation_0-auc:0.96147	validation_1-mlogloss:0.58847	validation_1-auc:0.94028
# [15]	validation_0-mlogloss:0.52360	validation_0-auc:0.96202	validation_1-mlogloss:0.57383	validation_1-auc:0.94049
# [16]	validation_0-mlogloss:0.50822	validation_0-auc:0.96250	validation_1-mlogloss:0.56090	validation_1-auc:0.94066
# [17]	validation_0-mlogloss:0.49443	validation_0-auc:0.96293	validation_1-mlogloss:0.54946	validation_1-auc:0.94083
# [18]	validation_0-mlogloss:0.48175	validation_0-auc:0.96343	validation_1-mlogloss:0.53932	validation_1-auc:0.94100
# [19]	validation_0-mlogloss:0.47011	validation_0-auc:0.96400	validation_1-mlogloss:0.53036	validation_1-auc:0.94119
# [20]	validation_0-mlogloss:0.45943	validation_0-auc:0.96458	validation_1-mlogloss:0.52234	validation_1-auc:0.94132
# ...
# [8]	validation_0-mlogloss:0.47051	validation_0-auc:0.94180	validation_1-mlogloss:0.47767	validation_1-auc:0.93951
# [9]	validation_0-mlogloss:0.46489	validation_0-auc:0.94262	validation_1-mlogloss:0.47329	validation_1-auc:0.94001
# [10]	validation_0-mlogloss:0.46079	validation_0-auc:0.94336	validation_1-mlogloss:0.47038	validation_1-auc:0.94036
# [11]	validation_0-mlogloss:0.45732	validation_0-auc:0.94407	validation_1-mlogloss:0.46793	validation_1-auc:0.94077
# [12]	validation_0-mlogloss:0.45444	validation_0-auc:0.94476	validation_1-mlogloss:0.46602	validation_1-auc:0.94121
# [13]	validation_0-mlogloss:0.45158	validation_0-auc:0.94550	validation_1-mlogloss:0.46442	validation_1-auc:0.94161
# [14]	validation_0-mlogloss:0.44909	validation_0-auc:0.94611	validation_1-mlogloss:0.46301	validation_1-auc:0.94195
# [15]	validation_0-mlogloss:0.44652	validation_0-auc:0.94677	validation_1-mlogloss:0.46209	validation_1-auc:0.94219
# [16]	validation_0-mlogloss:0.44438	validation_0-auc:0.94731	validation_1-mlogloss:0.46107	validation_1-auc:0.94242
# [17]	validation_0-mlogloss:0.44246	validation_0-auc:0.94781	validation_1-mlogloss:0.46037	validation_1-auc:0.94262
# [18]	validation_0-mlogloss:0.44072	validation_0-auc:0.94824	validation_1-mlogloss:0.45984	validation_1-auc:0.94274
# [19]	validation_0-mlogloss:0.43890	validation_0-auc:0.94872	validation_1-mlogloss:0.45936	validation_1-auc:0.94289
# [20]	validation_0-mlogloss:0.43754	validation_0-auc:0.94908	validation_1-mlogloss:0.45897	validation_1-auc:0.94300
# [21]	validation_0-mlogloss:0.43611	validation_0-auc:0.94943	validation_1-mlogloss:0.45876	validation_1-auc:0.94308
# [22]	validation_0-mlogloss:0.43465	validation_0-auc:0.94983	validation_1-mlogloss:0.45843	validation_1-auc:0.94316
# [23]	validation_0-mlogloss:0.43326	validation_0-auc:0.95018	validation_1-mlogloss:0.45845	validation_1-auc:0.94315
# [24]	validation_0-mlogloss:0.43190	validation_0-auc:0.95054	validation_1-mlogloss:0.45822	validation_1-auc:0.94325
# [25]	validation_0-mlogloss:0.43055	validation_0-auc:0.95089	validation_1-mlogloss:0.45783	validation_1-auc:0.94339
# [26]	validation_0-mlogloss:0.42932	validation_0-auc:0.95119	validation_1-mlogloss:0.45756	validation_1-auc:0.94348
# [27]	validation_0-mlogloss:0.42823	validation_0-auc:0.95147	validation_1-mlogloss:0.45735	validation_1-auc:0.94355
# [28]	validation_0-mlogloss:0.42683	validation_0-auc:0.95180	validation_1-mlogloss:0.45709	validation_1-auc:0.94365
# [29]	validation_0-mlogloss:0.42554	validation_0-auc:0.95212	validation_1-mlogloss:0.45694	validation_1-auc:0.94369
# [30]	validation_0-mlogloss:0.42433	validation_0-auc:0.95243	validation_1-mlogloss:0.45687	validation_1-auc:0.94371
# [31]	validation_0-mlogloss:0.42329	validation_0-auc:0.95267	validation_1-mlogloss:0.45680	validation_1-auc:0.94374
# [32]	validation_0-mlogloss:0.42212	validation_0-auc:0.95296	validation_1-mlogloss:0.45681	validation_1-auc:0.94374
# [33]	validation_0-mlogloss:0.42128	validation_0-auc:0.95317	validation_1-mlogloss:0.45688	validation_1-auc:0.94374
# [34]	validation_0-mlogloss:0.42021	validation_0-auc:0.95344	validation_1-mlogloss:0.45680	validation_1-auc:0.94376
# [35]	validation_0-mlogloss:0.41924	validation_0-auc:0.95368	validation_1-mlogloss:0.45672	validation_1-auc:0.94379
# [36]	validation_0-mlogloss:0.41824	validation_0-auc:0.95391	validation_1-mlogloss:0.45674	validation_1-auc:0.94380
# [37]	validation_0-mlogloss:0.41728	validation_0-auc:0.95416	validation_1-mlogloss:0.45661	validation_1-auc:0.94385
# [38]	validation_0-mlogloss:0.41618	validation_0-auc:0.95442	validation_1-mlogloss:0.45652	validation_1-auc:0.94388
# [39]	validation_0-mlogloss:0.41513	validation_0-auc:0.95469	validation_1-mlogloss:0.45630	validation_1-auc:0.94394
# [40]	validation_0-mlogloss:0.41411	validation_0-auc:0.95495	validation_1-mlogloss:0.45633	validation_1-auc:0.94394
# [41]	validation_0-mlogloss:0.41301	validation_0-auc:0.95519	validation_1-mlogloss:0.45638	validation_1-auc:0.94395
# [42]	validation_0-mlogloss:0.41215	validation_0-auc:0.95540	validation_1-mlogloss:0.45633	validation_1-auc:0.94396
# [43]	validation_0-mlogloss:0.41140	validation_0-auc:0.95558	validation_1-mlogloss:0.45632	validation_1-auc:0.94397
# [44]	validation_0-mlogloss:0.41053	validation_0-auc:0.95579	validation_1-mlogloss:0.45618	validation_1-auc:0.94401
# [45]	validation_0-mlogloss:0.40958	validation_0-auc:0.95600	validation_1-mlogloss:0.45624	validation_1-auc:0.94403
# [46]	validation_0-mlogloss:0.40864	validation_0-auc:0.95623	validation_1-mlogloss:0.45645	validation_1-auc:0.94398
# [47]	validation_0-mlogloss:0.40776	validation_0-auc:0.95643	validation_1-mlogloss:0.45652	validation_1-auc:0.94398
# [48]	validation_0-mlogloss:0.40681	validation_0-auc:0.95668	validation_1-mlogloss:0.45662	validation_1-auc:0.94396
# [49]	validation_0-mlogloss:0.40620	validation_0-auc:0.95682	validation_1-mlogloss:0.45662	validation_1-auc:0.94398
# [50]	validation_0-mlogloss:0.40540	validation_0-auc:0.95701	validation_1-mlogloss:0.45663	validation_1-auc:0.94399
# [51]	validation_0-mlogloss:0.40445	validation_0-auc:0.95724	validation_1-mlogloss:0.45664	validation_1-auc:0.94400
# [52]	validation_0-mlogloss:0.40368	validation_0-auc:0.95743	validation_1-mlogloss:0.45663	validation_1-auc:0.94402
# [53]	validation_0-mlogloss:0.40291	validation_0-auc:0.95760	validation_1-mlogloss:0.45667	validation_1-auc:0.94402
# [54]	validation_0-mlogloss:0.40199	validation_0-auc:0.95781	validation_1-mlogloss:0.45683	validation_1-auc:0.94398
# 0.8369240865882546
# 0.8139808533201621
# {'colsample_bytree': 0.31, 'gamma': 0.41000000000000003, 'learning_rate': 0.45, 'max_depth': 6, 'min_child_weight': 5.0, 'n_estimators': 75, 'subsample': 0.68}
#  90%|████████████████████████████████▍   | 18/20 [2:37:07<10:40, 320.31s/trial, best loss: -0.8171477548411464]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:0.94270	validation_0-auc:0.93440	validation_1-mlogloss:0.94834	validation_1-auc:0.92692
# [1]	validation_0-mlogloss:0.74799	validation_0-auc:0.94169	validation_1-mlogloss:0.75963	validation_1-auc:0.93300
# [2]	validation_0-mlogloss:0.63434	validation_0-auc:0.94506	validation_1-mlogloss:0.65189	validation_1-auc:0.93526
# [3]	validation_0-mlogloss:0.56287	validation_0-auc:0.94712	validation_1-mlogloss:0.58570	validation_1-auc:0.93671
# [4]	validation_0-mlogloss:0.51646	validation_0-auc:0.94871	validation_1-mlogloss:0.54387	validation_1-auc:0.93764
# [5]	validation_0-mlogloss:0.48448	validation_0-auc:0.95028	validation_1-mlogloss:0.51756	validation_1-auc:0.93813
# [6]	validation_0-mlogloss:0.46306	validation_0-auc:0.95142	validation_1-mlogloss:0.50001	validation_1-auc:0.93864
# [7]	validation_0-mlogloss:0.44762	validation_0-auc:0.95251	validation_1-mlogloss:0.48861	validation_1-auc:0.93913
# [8]	validation_0-mlogloss:0.43644	validation_0-auc:0.95345	validation_1-mlogloss:0.48114	validation_1-auc:0.93951
# [9]	validation_0-mlogloss:0.42773	validation_0-auc:0.95444	validation_1-mlogloss:0.47628	validation_1-auc:0.93982
# [10]	validation_0-mlogloss:0.42066	validation_0-auc:0.95541	validation_1-mlogloss:0.47333	validation_1-auc:0.94002
# [11]	validation_0-mlogloss:0.41457	validation_0-auc:0.95637	validation_1-mlogloss:0.47109	validation_1-auc:0.94036
# [12]	validation_0-mlogloss:0.40967	validation_0-auc:0.95719	validation_1-mlogloss:0.46971	validation_1-auc:0.94061
# [13]	validation_0-mlogloss:0.40607	validation_0-auc:0.95783	validation_1-mlogloss:0.46871	validation_1-auc:0.94082
# [14]	validation_0-mlogloss:0.40261	validation_0-auc:0.95847	validation_1-mlogloss:0.46855	validation_1-auc:0.94082
# [15]	validation_0-mlogloss:0.39871	validation_0-auc:0.95927	validation_1-mlogloss:0.46855	validation_1-auc:0.94082
# [16]	validation_0-mlogloss:0.39548	validation_0-auc:0.95993	validation_1-mlogloss:0.46849	validation_1-auc:0.94090
# [17]	validation_0-mlogloss:0.39169	validation_0-auc:0.96074	validation_1-mlogloss:0.46901	validation_1-auc:0.94082
# [18]	validation_0-mlogloss:0.38805	validation_0-auc:0.96147	validation_1-mlogloss:0.46914	validation_1-auc:0.94087
# [19]	validation_0-mlogloss:0.38505	validation_0-auc:0.96212	validation_1-mlogloss:0.46940	validation_1-auc:0.94086
# [20]	validation_0-mlogloss:0.38221	validation_0-auc:0.96272	validation_1-mlogloss:0.46974	validation_1-auc:0.94080
# [21]	validation_0-mlogloss:0.37962	validation_0-auc:0.96323	validation_1-mlogloss:0.47018	validation_1-auc:0.94075
# [22]	validation_0-mlogloss:0.37727	validation_0-auc:0.96376	validation_1-mlogloss:0.47083	validation_1-auc:0.94065
# [23]	validation_0-mlogloss:0.37464	validation_0-auc:0.96430	validation_1-mlogloss:0.47125	validation_1-auc:0.94063
# [24]	validation_0-mlogloss:0.37237	validation_0-auc:0.96473	validation_1-mlogloss:0.47189	validation_1-auc:0.94056
# [25]	validation_0-mlogloss:0.37024	validation_0-auc:0.96517	validation_1-mlogloss:0.47237	validation_1-auc:0.94052
# 0.8440791025338652
# 0.8102038148088964
# {'colsample_bytree': 0.8300000000000001, 'gamma': 0.44, 'learning_rate': 0.39, 'max_depth': 10, 'min_child_weight': 10.0, 'n_estimators': 35, 'subsample': 0.37}
#  95%|██████████████████████████████████▏ | 19/20 [2:44:21<05:54, 354.36s/trial, best loss: -0.8171477548411464]
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.08173	validation_0-auc:0.93387	validation_1-mlogloss:1.09206	validation_1-auc:0.91546
# [1]	validation_0-mlogloss:0.89777	validation_0-auc:0.94684	validation_1-mlogloss:0.91789	validation_1-auc:0.92707
# [2]	validation_0-mlogloss:0.77075	validation_0-auc:0.95244	validation_1-mlogloss:0.79891	validation_1-auc:0.93209
# [3]	validation_0-mlogloss:0.67824	validation_0-auc:0.95561	validation_1-mlogloss:0.71481	validation_1-auc:0.93416
# [4]	validation_0-mlogloss:0.60987	validation_0-auc:0.95779	validation_1-mlogloss:0.65409	validation_1-auc:0.93550
# [5]	validation_0-mlogloss:0.55765	validation_0-auc:0.95960	validation_1-mlogloss:0.60914	validation_1-auc:0.93640
# [6]	validation_0-mlogloss:0.51616	validation_0-auc:0.96147	validation_1-mlogloss:0.57511	validation_1-auc:0.93722
# [7]	validation_0-mlogloss:0.48406	validation_0-auc:0.96288	validation_1-mlogloss:0.54960	validation_1-auc:0.93780
# [8]	validation_0-mlogloss:0.45806	validation_0-auc:0.96421	validation_1-mlogloss:0.53031	validation_1-auc:0.93811
# [9]	validation_0-mlogloss:0.43741	validation_0-auc:0.96548	validation_1-mlogloss:0.51570	validation_1-auc:0.93859
# [10]	validation_0-mlogloss:0.42025	validation_0-auc:0.96667	validation_1-mlogloss:0.50491	validation_1-auc:0.93885
# [11]	validation_0-mlogloss:0.40548	validation_0-auc:0.96781	validation_1-mlogloss:0.49632	validation_1-auc:0.93910
# [12]	validation_0-mlogloss:0.39333	validation_0-auc:0.96876	validation_1-mlogloss:0.48931	validation_1-auc:0.93947
# [13]	validation_0-mlogloss:0.38320	validation_0-auc:0.96971	validation_1-mlogloss:0.48461	validation_1-auc:0.93965
# [14]	validation_0-mlogloss:0.37426	validation_0-auc:0.97065	validation_1-mlogloss:0.48068	validation_1-auc:0.93986
# [15]	validation_0-mlogloss:0.36667	validation_0-auc:0.97150	validation_1-mlogloss:0.47758	validation_1-auc:0.94002
# [16]	validation_0-mlogloss:0.35936	validation_0-auc:0.97239	validation_1-mlogloss:0.47525	validation_1-auc:0.94017
# [17]	validation_0-mlogloss:0.35373	validation_0-auc:0.97304	validation_1-mlogloss:0.47321	validation_1-auc:0.94050
# [18]	validation_0-mlogloss:0.34808	validation_0-auc:0.97377	validation_1-mlogloss:0.47191	validation_1-auc:0.94063
# [19]	validation_0-mlogloss:0.34245	validation_0-auc:0.97462	validation_1-mlogloss:0.47100	validation_1-auc:0.94073
# [20]	validation_0-mlogloss:0.33715	validation_0-auc:0.97540	validation_1-mlogloss:0.47027	validation_1-auc:0.94083
# [21]	validation_0-mlogloss:0.33171	validation_0-auc:0.97618	validation_1-mlogloss:0.47001	validation_1-auc:0.94086
# [22]	validation_0-mlogloss:0.32733	validation_0-auc:0.97685	validation_1-mlogloss:0.46960	validation_1-auc:0.94097
# [23]	validation_0-mlogloss:0.32348	validation_0-auc:0.97747	validation_1-mlogloss:0.46942	validation_1-auc:0.94105
# [24]	validation_0-mlogloss:0.31971	validation_0-auc:0.97807	validation_1-mlogloss:0.46935	validation_1-auc:0.94108
# [25]	validation_0-mlogloss:0.31494	validation_0-auc:0.97883	validation_1-mlogloss:0.46938	validation_1-auc:0.94109
# [26]	validation_0-mlogloss:0.31125	validation_0-auc:0.97941	validation_1-mlogloss:0.46942	validation_1-auc:0.94111
# [27]	validation_0-mlogloss:0.30766	validation_0-auc:0.97998	validation_1-mlogloss:0.46942	validation_1-auc:0.94112
# [28]	validation_0-mlogloss:0.30401	validation_0-auc:0.98062	validation_1-mlogloss:0.46934	validation_1-auc:0.94118
# [29]	validation_0-mlogloss:0.30031	validation_0-auc:0.98118	validation_1-mlogloss:0.46958	validation_1-auc:0.94121
# [30]	validation_0-mlogloss:0.29740	validation_0-auc:0.98168	validation_1-mlogloss:0.46967	validation_1-auc:0.94119
# [31]	validation_0-mlogloss:0.29425	validation_0-auc:0.98221	validation_1-mlogloss:0.47015	validation_1-auc:0.94110
# [32]	validation_0-mlogloss:0.29041	validation_0-auc:0.98287	validation_1-mlogloss:0.47049	validation_1-auc:0.94104
# [33]	validation_0-mlogloss:0.28758	validation_0-auc:0.98331	validation_1-mlogloss:0.47054	validation_1-auc:0.94108
# [34]	validation_0-mlogloss:0.28455	validation_0-auc:0.98382	validation_1-mlogloss:0.47064	validation_1-auc:0.94115
# [35]	validation_0-mlogloss:0.28224	validation_0-auc:0.98421	validation_1-mlogloss:0.47080	validation_1-auc:0.94112
# [36]	validation_0-mlogloss:0.27878	validation_0-auc:0.98474	validation_1-mlogloss:0.47090	validation_1-auc:0.94116
# [37]	validation_0-mlogloss:0.27585	validation_0-auc:0.98515	validation_1-mlogloss:0.47126	validation_1-auc:0.94110
# [38]	validation_0-mlogloss:0.27283	validation_0-auc:0.98563	validation_1-mlogloss:0.47146	validation_1-auc:0.94114
# [39]	validation_0-mlogloss:0.26980	validation_0-auc:0.98614	validation_1-mlogloss:0.47171	validation_1-auc:0.94108
# 0.9031573334427138
# 0.8103200313784737
# {'colsample_bytree': 0.33, 'gamma': 0.34, 'learning_rate': 0.25, 'max_depth': 13, 'min_child_weight': 7.0, 'n_estimators': 55, 'subsample': 0.43}
# 100%|████████████████████████████████████| 20/20 [2:51:20<00:00, 514.04s/trial, best loss: -0.8171477548411464]

# %% [markdown]
# 0.8554717542222541
# 0.8153173438703023
# {'colsample_bytree': 0.39, 'gamma': 0.47000000000000003, 'learning_rate': 0.26, 'max_depth': 7, 'min_child_weight': 5.0, 'n_estimators': 90, 'subsample': 0.6900000000000001}

# %% [markdown]
# 0.8385289020601113
# 0.8165376178508651
# {'colsample_bytree': 0.93, 'gamma': 0.15, 'learning_rate': 0.04, 'max_depth': 8, 'min_child_weight': 5.0, 'n_estimators': 175, 'subsample': 0.72}

# %%
bestParams = {'colsample_bytree': 0.68, 'gamma': 0.41000000000000003, 'learning_rate': 0.11, 'max_depth': 8, 'min_child_weight': 3.0, 'n_estimators': 80, 'subsample': 0.75}

#generate xgboost classifier
xgb = XGB.XGBClassifier(**bestParams,
                    verbosity=1,
                   eval_metric=['mlogloss', 'auc'])
model = xgb.fit(x_train_1, y_train_1, eval_set=[(x_train_1, y_train_1), (x_val, y_val)], verbose=1, early_stopping_rounds=5,)
preds_tr = xgb.predict(x_train_1)
preds_val = xgb.predict(x_val)
# Out:
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:1.24635	validation_0-auc:0.93323	validation_1-mlogloss:1.24710	validation_1-auc:0.92878
# [1]	validation_0-mlogloss:1.13618	validation_0-auc:0.93859	validation_1-mlogloss:1.13785	validation_1-auc:0.93396
# [2]	validation_0-mlogloss:1.04513	validation_0-auc:0.94035	validation_1-mlogloss:1.04763	validation_1-auc:0.93559
# [3]	validation_0-mlogloss:0.96869	validation_0-auc:0.94138	validation_1-mlogloss:0.97222	validation_1-auc:0.93643
# [4]	validation_0-mlogloss:0.90410	validation_0-auc:0.94209	validation_1-mlogloss:0.90845	validation_1-auc:0.93697
# [5]	validation_0-mlogloss:0.84882	validation_0-auc:0.94283	validation_1-mlogloss:0.85423	validation_1-auc:0.93746
# [6]	validation_0-mlogloss:0.80091	validation_0-auc:0.94332	validation_1-mlogloss:0.80721	validation_1-auc:0.93781
# [7]	validation_0-mlogloss:0.75907	validation_0-auc:0.94370	validation_1-mlogloss:0.76629	validation_1-auc:0.93811
# [8]	validation_0-mlogloss:0.72272	validation_0-auc:0.94410	validation_1-mlogloss:0.73080	validation_1-auc:0.93828
# [9]	validation_0-mlogloss:0.69080	validation_0-auc:0.94471	validation_1-mlogloss:0.69994	validation_1-auc:0.93873
# [10]	validation_0-mlogloss:0.66288	validation_0-auc:0.94519	validation_1-mlogloss:0.67285	validation_1-auc:0.93906
# [11]	validation_0-mlogloss:0.63793	validation_0-auc:0.94551	validation_1-mlogloss:0.64896	validation_1-auc:0.93921
# [12]	validation_0-mlogloss:0.61586	validation_0-auc:0.94585	validation_1-mlogloss:0.62777	validation_1-auc:0.93944
# [13]	validation_0-mlogloss:0.59625	validation_0-auc:0.94618	validation_1-mlogloss:0.60910	validation_1-auc:0.93959
# [14]	validation_0-mlogloss:0.57893	validation_0-auc:0.94656	validation_1-mlogloss:0.59262	validation_1-auc:0.93983
# [15]	validation_0-mlogloss:0.56348	validation_0-auc:0.94685	validation_1-mlogloss:0.57801	validation_1-auc:0.93998
# [16]	validation_0-mlogloss:0.54962	validation_0-auc:0.94715	validation_1-mlogloss:0.56503	validation_1-auc:0.94012
# [17]	validation_0-mlogloss:0.53716	validation_0-auc:0.94755	validation_1-mlogloss:0.55352	validation_1-auc:0.94032
# [18]	validation_0-mlogloss:0.52608	validation_0-auc:0.94788	validation_1-mlogloss:0.54340	validation_1-auc:0.94047
# [19]	validation_0-mlogloss:0.51610	validation_0-auc:0.94824	validation_1-mlogloss:0.53431	validation_1-auc:0.94064
# [20]	validation_0-mlogloss:0.50708	validation_0-auc:0.94861	validation_1-mlogloss:0.52621	validation_1-auc:0.94083
# [21]	validation_0-mlogloss:0.49884	validation_0-auc:0.94894	validation_1-mlogloss:0.51891	validation_1-auc:0.94096
# [22]	validation_0-mlogloss:0.49151	validation_0-auc:0.94921	validation_1-mlogloss:0.51247	validation_1-auc:0.94105
# [23]	validation_0-mlogloss:0.48467	validation_0-auc:0.94964	validation_1-mlogloss:0.50667	validation_1-auc:0.94125
# [24]	validation_0-mlogloss:0.47865	validation_0-auc:0.94993	validation_1-mlogloss:0.50160	validation_1-auc:0.94135
# [25]	validation_0-mlogloss:0.47308	validation_0-auc:0.95024	validation_1-mlogloss:0.49697	validation_1-auc:0.94149
# [26]	validation_0-mlogloss:0.46799	validation_0-auc:0.95057	validation_1-mlogloss:0.49283	validation_1-auc:0.94165
# [27]	validation_0-mlogloss:0.46338	validation_0-auc:0.95091	validation_1-mlogloss:0.48913	validation_1-auc:0.94179
# [28]	validation_0-mlogloss:0.45915	validation_0-auc:0.95127	validation_1-mlogloss:0.48574	validation_1-auc:0.94195
# [29]	validation_0-mlogloss:0.45527	validation_0-auc:0.95153	validation_1-mlogloss:0.48271	validation_1-auc:0.94205
# [30]	validation_0-mlogloss:0.45172	validation_0-auc:0.95181	validation_1-mlogloss:0.47999	validation_1-auc:0.94215
# [31]	validation_0-mlogloss:0.44837	validation_0-auc:0.95215	validation_1-mlogloss:0.47750	validation_1-auc:0.94228
# [32]	validation_0-mlogloss:0.44534	validation_0-auc:0.95246	validation_1-mlogloss:0.47540	validation_1-auc:0.94240
# [33]	validation_0-mlogloss:0.44260	validation_0-auc:0.95273	validation_1-mlogloss:0.47338	validation_1-auc:0.94251
# [34]	validation_0-mlogloss:0.43991	validation_0-auc:0.95302	validation_1-mlogloss:0.47160	validation_1-auc:0.94259
# [35]	validation_0-mlogloss:0.43738	validation_0-auc:0.95331	validation_1-mlogloss:0.47002	validation_1-auc:0.94266
# [36]	validation_0-mlogloss:0.43508	validation_0-auc:0.95360	validation_1-mlogloss:0.46854	validation_1-auc:0.94276
# [37]	validation_0-mlogloss:0.43297	validation_0-auc:0.95384	validation_1-mlogloss:0.46724	validation_1-auc:0.94284
# [38]	validation_0-mlogloss:0.43095	validation_0-auc:0.95410	validation_1-mlogloss:0.46603	validation_1-auc:0.94293
# [39]	validation_0-mlogloss:0.42905	validation_0-auc:0.95437	validation_1-mlogloss:0.46498	validation_1-auc:0.94301
# [40]	validation_0-mlogloss:0.42715	validation_0-auc:0.95469	validation_1-mlogloss:0.46403	validation_1-auc:0.94309
# [41]	validation_0-mlogloss:0.42534	validation_0-auc:0.95496	validation_1-mlogloss:0.46304	validation_1-auc:0.94319
# [42]	validation_0-mlogloss:0.42390	validation_0-auc:0.95518	validation_1-mlogloss:0.46228	validation_1-auc:0.94325
# [43]	validation_0-mlogloss:0.42237	validation_0-auc:0.95541	validation_1-mlogloss:0.46153	validation_1-auc:0.94332
# [44]	validation_0-mlogloss:0.42090	validation_0-auc:0.95566	validation_1-mlogloss:0.46080	validation_1-auc:0.94341
# [45]	validation_0-mlogloss:0.41934	validation_0-auc:0.95594	validation_1-mlogloss:0.46013	validation_1-auc:0.94351
# [46]	validation_0-mlogloss:0.41809	validation_0-auc:0.95613	validation_1-mlogloss:0.45958	validation_1-auc:0.94356
# [47]	validation_0-mlogloss:0.41674	validation_0-auc:0.95639	validation_1-mlogloss:0.45901	validation_1-auc:0.94364
# [48]	validation_0-mlogloss:0.41548	validation_0-auc:0.95661	validation_1-mlogloss:0.45849	validation_1-auc:0.94371
# [49]	validation_0-mlogloss:0.41430	validation_0-auc:0.95682	validation_1-mlogloss:0.45804	validation_1-auc:0.94377
# [50]	validation_0-mlogloss:0.41314	validation_0-auc:0.95704	validation_1-mlogloss:0.45766	validation_1-auc:0.94381
# [51]	validation_0-mlogloss:0.41202	validation_0-auc:0.95724	validation_1-mlogloss:0.45716	validation_1-auc:0.94389
# [52]	validation_0-mlogloss:0.41089	validation_0-auc:0.95745	validation_1-mlogloss:0.45678	validation_1-auc:0.94395
# [53]	validation_0-mlogloss:0.40978	validation_0-auc:0.95768	validation_1-mlogloss:0.45647	validation_1-auc:0.94400
# [54]	validation_0-mlogloss:0.40866	validation_0-auc:0.95791	validation_1-mlogloss:0.45614	validation_1-auc:0.94406
# [55]	validation_0-mlogloss:0.40764	validation_0-auc:0.95812	validation_1-mlogloss:0.45579	validation_1-auc:0.94413
# [56]	validation_0-mlogloss:0.40655	validation_0-auc:0.95837	validation_1-mlogloss:0.45552	validation_1-auc:0.94418
# [57]	validation_0-mlogloss:0.40552	validation_0-auc:0.95858	validation_1-mlogloss:0.45526	validation_1-auc:0.94422
# [58]	validation_0-mlogloss:0.40446	validation_0-auc:0.95880	validation_1-mlogloss:0.45499	validation_1-auc:0.94427
# [59]	validation_0-mlogloss:0.40356	validation_0-auc:0.95900	validation_1-mlogloss:0.45477	validation_1-auc:0.94432
# [60]	validation_0-mlogloss:0.40254	validation_0-auc:0.95923	validation_1-mlogloss:0.45455	validation_1-auc:0.94436
# [61]	validation_0-mlogloss:0.40147	validation_0-auc:0.95946	validation_1-mlogloss:0.45426	validation_1-auc:0.94442
# [62]	validation_0-mlogloss:0.40046	validation_0-auc:0.95969	validation_1-mlogloss:0.45405	validation_1-auc:0.94446
# [63]	validation_0-mlogloss:0.39949	validation_0-auc:0.95992	validation_1-mlogloss:0.45387	validation_1-auc:0.94449
# [64]	validation_0-mlogloss:0.39855	validation_0-auc:0.96014	validation_1-mlogloss:0.45366	validation_1-auc:0.94454
# [65]	validation_0-mlogloss:0.39752	validation_0-auc:0.96037	validation_1-mlogloss:0.45348	validation_1-auc:0.94460
# [66]	validation_0-mlogloss:0.39666	validation_0-auc:0.96057	validation_1-mlogloss:0.45331	validation_1-auc:0.94463
# [67]	validation_0-mlogloss:0.39574	validation_0-auc:0.96078	validation_1-mlogloss:0.45320	validation_1-auc:0.94466
# [68]	validation_0-mlogloss:0.39497	validation_0-auc:0.96096	validation_1-mlogloss:0.45305	validation_1-auc:0.94468
# [69]	validation_0-mlogloss:0.39402	validation_0-auc:0.96118	validation_1-mlogloss:0.45294	validation_1-auc:0.94471
# [70]	validation_0-mlogloss:0.39314	validation_0-auc:0.96140	validation_1-mlogloss:0.45278	validation_1-auc:0.94475
# [71]	validation_0-mlogloss:0.39228	validation_0-auc:0.96160	validation_1-mlogloss:0.45257	validation_1-auc:0.94480
# [72]	validation_0-mlogloss:0.39139	validation_0-auc:0.96181	validation_1-mlogloss:0.45246	validation_1-auc:0.94483
# [73]	validation_0-mlogloss:0.39044	validation_0-auc:0.96203	validation_1-mlogloss:0.45236	validation_1-auc:0.94485
# [74]	validation_0-mlogloss:0.38957	validation_0-auc:0.96224	validation_1-mlogloss:0.45226	validation_1-auc:0.94488
# [75]	validation_0-mlogloss:0.38871	validation_0-auc:0.96243	validation_1-mlogloss:0.45218	validation_1-auc:0.94490
# [76]	validation_0-mlogloss:0.38790	validation_0-auc:0.96261	validation_1-mlogloss:0.45209	validation_1-auc:0.94493
# [77]	validation_0-mlogloss:0.38693	validation_0-auc:0.96283	validation_1-mlogloss:0.45197	validation_1-auc:0.94496
# [78]	validation_0-mlogloss:0.38606	validation_0-auc:0.96303	validation_1-mlogloss:0.45187	validation_1-auc:0.94498
# [79]	validation_0-mlogloss:0.38540	validation_0-auc:0.96318	validation_1-mlogloss:0.45177	validation_1-auc:0.94500
# 0.8171477548411464

# %%
accuracy_score(y_train_1, preds_tr)
# Out:
# 0.8474810037018428

# %%
accuracy_score(y_val, preds_val)
# Out:
# 0.8171477548411464

# %%
probs_tr = xgb.predict_proba(x_train_1)
probs_val = xgb.predict_proba(x_val)

# %%
np.save("Preds/XGB_val", probs_val)
np.save("Preds/XGB_tr", probs_tr)

probs_test = xgb.predict_proba(x_test)
np.save("Preds/XGB_test", probs_test)
