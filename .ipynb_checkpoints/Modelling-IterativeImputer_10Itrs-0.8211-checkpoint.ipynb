# %%
import numpy as np
import pandas as pd
# library for splitting training-testing
from sklearn.model_selection import train_test_split
# library for classification
from sklearn.metrics import accuracy_score

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# x_train = pd.read_csv("Data/train_allx.csv")
# x_test = pd.read_csv("Data/val_allx.csv")
# x_train.drop('ID', axis=1 , inplace=True)
# x_test.drop('ID', axis=1 , inplace=True)

# x_train = pd.read_csv("Data/train_x_null<50_notImputed.csv")
# x_test = pd.read_csv("Data/test_x_null<50_notImputed.csv")

# x_train = pd.read_csv("Data/train__mean_mode_Imputed.csv")
# x_test = pd.read_csv("Data/test__mean_mode_Imputed.csv")

# x_train = pd.read_csv("Data/train__Varstack_Imputed.csv")
# x_test = pd.read_csv("Data/test__Verstack_Imputed.csv")

# x_train = pd.read_csv("Data/train__Mean_MissingIndicator_Imputed.csv")
# x_test = pd.read_csv("Data/test__Mean_MissingIndicator_Imputed.csv")

x_train = pd.read_feather("Data/x_train__IterativeImputer_10itrs.ftr")
x_test = pd.read_feather("Data/x_test__IterativeImputer_10itrs.ftr")

# x_train = pd.read_feather("Data/x_train__groupbyInputed.ftr")
# x_test = pd.read_feather("Data/x_test__groupbyInputed.ftr")

y_train = pd.read_csv("Data/train_y.csv")
y_test = pd.read_csv("Data/Sample_Output.csv", names = ['ID', 'Target'], header=None)

# %%
x_train
# Out:
#             B_37      S_24       S_4      S_14      B_25      D_38      B_30  \
# 0       0.006462  0.008118  0.853027  0.556641  1.003906  0.276992  0.021301
# 1       0.007748  0.006310  0.758301  0.686035  0.001836  0.067099  0.088501
# 2       0.005405  0.005219  0.766602  0.284668  1.002930  0.276992  0.005821
# 3       0.004135  0.000032  0.363281  0.004623  0.533691  0.115178  0.002443
# 4       0.002968  0.002892  0.757324  0.427734  1.001953  0.059624  0.008247
# ...          ...       ...       ...       ...       ...       ...       ...
# 458908  0.003967  0.005070  0.167480  0.421143  0.697266  0.276992  0.059113
# 458909  0.006248  0.007683  0.003338  0.006954  1.004883  0.293997  0.001700
# 458910  0.004993  0.003204  0.167114  0.289307  0.650879  0.115178  0.007294
# 458911  0.002348  0.005432  0.330078  0.003138  0.689941  0.276992  0.001930
# 458912  0.009079  0.009773  0.000458  0.004875  1.001953  0.288726  0.007450
#
#            D_138       P_2       S_7  ...      D_43       D_4      D_85  \
# 0       0.511230  1.004883  0.081543  ...  0.031038  0.502441  0.002375
# 1       0.557129  0.687988  0.353027  ...  0.072340  0.009544  1.002930
# 2       0.854980  0.927734  0.059479  ...  0.031038  0.008736  0.008751
# 3       0.526367  0.700684  0.334473  ...  0.011714  0.004646  0.007095
# 4       0.820312  1.001953  0.144287  ...  0.004537  0.000344  0.005577
# ...          ...       ...       ...  ...       ...       ...       ...
# 458908  0.526855  0.852051  0.724121  ...  0.031038  0.005363  0.001710
# 458909  0.575195  0.885254  0.255878  ...  0.047829  0.008728  0.008682
# 458910  0.406738  0.632324  0.346924  ...  0.011714  0.002733  0.000283
# 458911  0.417969  0.846191  0.172607  ...  0.031038  0.007492  0.009583
# 458912  0.602051  0.715332  0.299080  ...  0.085619  0.006264  0.000527
#
#             D_78      D_42      D_52      D_29       R_1      R_28       S_5
# 0       0.008270  0.008835  0.001913  1.007812  0.008171  0.008514  0.004307
# 1       0.002613  0.003374  0.000530  0.006649  0.006798  0.003426  0.009224
# 2       0.002541  0.009300  0.001654  0.000212  0.007599  0.009224  0.009636
# 3       0.000235  0.004581  0.004738  0.002653  0.001221  0.009529  0.007523
# 4       0.001367  0.005760  1.008789  1.003906  0.003401  0.001020  0.000535
# ...          ...       ...       ...       ...       ...       ...       ...
# 458908  0.001604  0.001387  0.009468  0.000110  0.009346  0.009995  0.001259
# 458909  0.008438  0.008392  0.006836  0.004223  0.008179  0.004337  0.003376
# 458910  0.009102  0.000087  0.007229  0.000245  0.007935  0.007233  0.007114
# 458911  0.001172  0.005016  0.002506  0.009796  0.001634  0.009781  0.003271
# 458912  0.002682  0.004135  0.006561  0.003550  0.003838  0.003283  0.007168
#
# [458913 rows x 188 columns]

# %% [markdown]
# # Categorical to OneHot

# %%
# x_train = pd.get_dummies(x_train, columns=["D_36", "D_44"], prefix=["D_36", "D_44"], 
#                drop_first=True, dummy_na=True)

# x_test = pd.get_dummies(x_test, columns=["D_36", "D_44"], prefix=["D_36", "D_44"], 
#                drop_first=True, dummy_na=True)

# %% [markdown]
# # Test Train Split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.15, random_state=59, stratify=y_train)

# %%
x_train
# Out:
#             B_37      S_24       S_4      S_14      B_25      D_38      B_30  \
# 204902  0.000537  0.002211  0.753418  0.426758  1.004883  0.067099  0.031372
# 379883  1.009766  0.004143  0.009712  0.007290  0.054077  0.276992  0.540527
# 129737  0.000283  0.004601  0.173340  0.286865  0.419678  0.297414  0.087952
# 73910   0.009575  0.001327  0.103271  0.005520  0.243042  0.276992  0.572754
# 216625  0.006859  0.005913  0.757324  0.844727  1.008789  0.115178  0.009346
# ...          ...       ...       ...       ...       ...       ...       ...
# 294509  0.000364  0.009514  0.009933  0.000112  0.240112  0.297414  0.572754
# 234469  0.006172  0.008919  0.760742  0.850098  1.005859  0.297414  0.060883
# 283661  0.034393  0.005027  0.328257  0.262565  0.569870  0.246377  0.205738
# 418453  0.006802  0.004635  0.854980  0.533203  1.004883  0.276992  0.036621
# 298858  1.005859  0.003828  0.174683  0.285889  0.103088  0.293997  0.439453
#
#            D_138       P_2       S_7  ...      D_43       D_4      D_85  \
# 204902  0.580566  0.897461  0.166138  ...  0.072340  0.503906  0.004406
# 379883  0.291504  0.332520  0.201248  ...  0.031038  0.009392  0.004028
# 129737  0.358643  0.464355  0.405273  ...  0.042480  0.008560  0.003397
# 73910   0.454834  0.205078  0.187012  ...  0.031038  0.007553  0.008064
# 216625  0.685547  0.896973  0.137207  ...  0.011714  0.008209  0.009911
# ...          ...       ...       ...  ...       ...       ...       ...
# 294509  0.093506  0.379639  0.253174  ...  0.042480  0.000362  0.005444
# 234469  0.270264  0.950684  0.106018  ...  0.042480  0.008560  0.000295
# 283661  0.398812  0.636767  0.232033  ...  0.047461  0.062069  0.037095
# 418453  0.595703  1.004883  0.015427  ...  0.031038  0.005577  0.002256
# 298858  0.273193  0.446289  0.201538  ...  0.047829  0.005497  0.005909
#
#             D_78      D_42      D_52      D_29       R_1      R_28       S_5
# 204902  1.004883  0.003769  1.008789  0.000290  0.003925  0.008804  0.008736
# 379883  0.004162  0.002605  0.008644  0.007305  0.008751  1.004883  0.004345
# 129737  0.003689  0.008766  0.003906  0.006405  0.005093  0.005020  0.008133
# 73910   0.009392  0.000085  0.007717  0.002220  0.006325  0.003218  0.005116
# 216625  1.007812  0.004169  1.009766  1.004883  0.004784  0.006775  0.001021
# ...          ...       ...       ...       ...       ...       ...       ...
# 294509  0.005669  0.005741  0.004036  0.001136  0.003677  0.003582  0.003323
# 234469  0.005608  0.005089  0.007069  1.003906  0.000380  0.001028  0.008766
# 283661  0.022498  0.012996  0.093292  0.113686  0.005475  0.027476  0.016770
# 418453  0.003290  0.000010  0.009666  0.004665  0.009491  0.001995  0.005501
# 298858  0.008347  0.005520  0.002523  0.009628  0.002367  0.003452  0.008537
#
# [390076 rows x 188 columns]

# %%
x_val
# Out:
#             B_37      S_24       S_4      S_14      B_25      D_38      B_30  \
# 352262  0.006382  0.005024  0.008347  0.003109  1.002930  0.293997  0.000047
# 81404   0.005367  0.007484  0.319336  0.285645  0.481201  0.293997  0.013557
# 355900  0.000736  0.003660  0.008263  0.002398  0.051575  0.276992  0.468506
# 64818   0.001374  0.008667  0.472656  0.000304  0.526367  0.115178  0.007141
# 101079  0.003305  0.005138  0.758301  0.424805  1.007812  0.276992  0.092468
# ...          ...       ...       ...       ...       ...       ...       ...
# 164679  0.001330  0.005997  0.324463  0.846680  1.004883  0.297414  0.078918
# 411078  0.004597  0.007481  0.666992  0.557617  0.145508  0.115178  0.006599
# 278203  0.005417  0.004021  0.603027  0.288330  0.691895  0.277307  0.000612
# 16462   0.005165  0.000354  0.406982  0.282471  0.324463  0.297414  0.461914
# 271188  0.007957  0.003727  0.001541  0.003885  0.589844  0.277307  0.006088
#
#            D_138       P_2       S_7  ...      D_43       D_4      D_85  \
# 352262  0.470215  0.858398  0.255878  ...  0.047829  0.005009  0.002117
# 81404   0.488037  0.765137  0.175659  ...  0.047829  0.009300  0.002279
# 355900  0.272461  0.312988  0.616699  ...  0.031038  0.005592  0.006058
# 64818   0.159180  0.562500  0.138916  ...  0.011714  0.008965  0.009857
# 101079  0.410156  0.785645  0.059998  ...  0.031038  0.500000  0.002777
# ...          ...       ...       ...  ...       ...       ...       ...
# 164679  0.505371  0.879883  0.142822  ...  0.042480  0.009560  0.008553
# 411078  0.439453  0.955566  0.138672  ...  0.011714  0.006859  0.003267
# 278203  0.142212  0.830566  0.103577  ...  0.103824  0.003571  0.003220
# 16462   0.143188  0.308594  0.156738  ...  0.042480  0.008446  0.008156
# 271188  0.273438  0.659180  0.284702  ...  0.103824  0.008194  0.007641
#
#             D_78      D_42      D_52      D_29       R_1      R_28       S_5
# 352262  0.000114  0.008598  0.001371  0.002628  0.006397  0.001836  0.006718
# 81404   0.002810  0.002523  0.004604  0.006680  0.000923  0.006676  0.001885
# 355900  0.007866  0.001815  0.005089  0.005852  0.001149  0.003355  0.002525
# 64818   0.001804  0.003208  0.006157  0.007904  0.002432  0.007553  0.005260
# 101079  0.006496  0.009872  1.007812  1.003906  0.008339  0.008820  0.009735
# ...          ...       ...       ...       ...       ...       ...       ...
# 164679  0.009781  0.004700  0.000100  0.005886  0.000421  0.007240  0.005848
# 411078  0.008911  1.004883  0.007301  0.009232  0.006432  0.005173  0.003616
# 278203  0.004551  0.006237  0.007416  0.004990  0.005089  0.003588  0.006371
# 16462   0.007484  0.009651  0.007206  0.003601  0.005623  0.004398  0.008347
# 271188  0.000441  0.000401  0.009949  0.001202  0.006264  0.008789  0.008034
#
# [68837 rows x 188 columns]

# %% [markdown]
# # LightGBM

# %%
categorical_feats = x_train.select_dtypes('object').columns.tolist()
for c in categorical_feats:
    x_train[c] = x_train[c].astype('category')
    x_val[c] = x_val[c].astype('category')
    x_test[c] = x_test[c].astype('category')

# %%
import lightgbm as lgb
print ('Training lightgbm')

# money
params = {
          "objective" : "multiclass",
          "num_class" : 4,
          "num_leaves" : 100,
          "max_depth": 8,
          "learning_rate" : 0.02,
          "bagging_fraction" : 0.9,  # subsample
          "feature_fraction" : 0.9,  # colsample_bytree
          "bagging_freq" : 5,        # subsample_freq
          "bagging_seed" : 2018,
          "verbosity" : -1,
          "metric" : ['auc_mu', 'multi_logloss'],
          "min_data_in_leaf" : 5000,
#           'categorical_feature' : x_train.select_dtypes('object').columns.tolist(),
#             'boosting' : 'dart',
            'num_threads' : 8,
#             'xgboost_dart_mode' : True,
            'is_unbalance' : True,
#             'class_weight' : 'balanced',
            'n_estimators' : 500
}
# Out:
# Training lightgbm

# %%
params = {'task': 'train',
 'learning_rate': 0.05,
 'num_leaves': 66,
 'colsample_bytree': 0.9162213204002109,
 'subsample': 0.5909124836035503,
 'bagging_freq': 1,
 'max_depth': -1,
 'verbosity': -1,
 'reg_alpha': 5.472429642032198e-06,
 'reg_lambda': 0.00052821153945323,
 'min_split_gain': 0.0,
 'zero_as_missing': False,
 'max_bin': 255,
 'min_data_in_bin': 3,
 'random_state': 42,
 'num_classes': 4,
 'objective': 'multiclass',
 'metric': 'multi_logloss',
 'num_threads': 8,
 'min_sum_hessian_in_leaf': 0.00541524411940254,
 'n_estimators': 292,
 "metric" : ['auc_mu', 'multi_logloss'],}

# %%
# %%time

lgbc = lgb.LGBMClassifier(**params)
lgbmodel = lgbc.fit(x_train,y_train, eval_set=[(x_train, y_train), (x_val, y_val)], early_stopping_rounds=40, verbose=1)
# Out:
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] num_threads is set=8, n_jobs=-1 will be ignored. Current value: num_threads=8
# [LightGBM] [Warning] min_data_in_leaf is set=5000, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5000
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /home/jindalmadhur26/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [1]	training's auc_mu: 0.831524	training's multi_logloss: 0.835899	valid_1's auc_mu: 0.830941	valid_1's multi_logloss: 0.835889
# [2]	training's auc_mu: 0.83599	training's multi_logloss: 0.819063	valid_1's auc_mu: 0.835001	valid_1's multi_logloss: 0.819041
# [3]	training's auc_mu: 0.83793	training's multi_logloss: 0.804149	valid_1's auc_mu: 0.836536	valid_1's multi_logloss: 0.804137
# [4]	training's auc_mu: 0.838693	training's multi_logloss: 0.78993	valid_1's auc_mu: 0.83718	valid_1's multi_logloss: 0.789927
# [5]	training's auc_mu: 0.839595	training's multi_logloss: 0.776817	valid_1's auc_mu: 0.838002	valid_1's multi_logloss: 0.776836
# [6]	training's auc_mu: 0.840473	training's multi_logloss: 0.764584	valid_1's auc_mu: 0.838761	valid_1's multi_logloss: 0.764612
# [7]	training's auc_mu: 0.841375	training's multi_logloss: 0.753198	valid_1's auc_mu: 0.839452	valid_1's multi_logloss: 0.753233
# [8]	training's auc_mu: 0.842227	training's multi_logloss: 0.742457	valid_1's auc_mu: 0.840089	valid_1's multi_logloss: 0.742521
# [9]	training's auc_mu: 0.842664	training's multi_logloss: 0.732259	valid_1's auc_mu: 0.840597	valid_1's multi_logloss: 0.732326
# [10]	training's auc_mu: 0.843196	training's multi_logloss: 0.722667	valid_1's auc_mu: 0.841058	valid_1's multi_logloss: 0.722751
# [11]	training's auc_mu: 0.843508	training's multi_logloss: 0.713607	valid_1's auc_mu: 0.841422	valid_1's multi_logloss: 0.713692
# [12]	training's auc_mu: 0.84388	training's multi_logloss: 0.705009	valid_1's auc_mu: 0.84178	valid_1's multi_logloss: 0.7051
# [13]	training's auc_mu: 0.844471	training's multi_logloss: 0.696861	valid_1's auc_mu: 0.84213	valid_1's multi_logloss: 0.696978
# [14]	training's auc_mu: 0.844856	training's multi_logloss: 0.689075	valid_1's auc_mu: 0.842403	valid_1's multi_logloss: 0.689217
# [15]	training's auc_mu: 0.84528	training's multi_logloss: 0.681669	valid_1's auc_mu: 0.842791	valid_1's multi_logloss: 0.681832
# [16]	training's auc_mu: 0.84576	training's multi_logloss: 0.674651	valid_1's auc_mu: 0.843237	valid_1's multi_logloss: 0.674817
# [17]	training's auc_mu: 0.846193	training's multi_logloss: 0.667904	valid_1's auc_mu: 0.843583	valid_1's multi_logloss: 0.668082
# [18]	training's auc_mu: 0.846608	training's multi_logloss: 0.661485	valid_1's auc_mu: 0.843865	valid_1's multi_logloss: 0.661677
# [19]	training's auc_mu: 0.846998	training's multi_logloss: 0.6553	valid_1's auc_mu: 0.84419	valid_1's multi_logloss: 0.655511
# [20]	training's auc_mu: 0.847385	training's multi_logloss: 0.649421	valid_1's auc_mu: 0.844572	valid_1's multi_logloss: 0.649632
# [21]	training's auc_mu: 0.847698	training's multi_logloss: 0.64375	valid_1's auc_mu: 0.844828	valid_1's multi_logloss: 0.643989
# [22]	training's auc_mu: 0.847943	training's multi_logloss: 0.63839	valid_1's auc_mu: 0.845135	valid_1's multi_logloss: 0.638636
# [23]	training's auc_mu: 0.84817	training's multi_logloss: 0.633214	valid_1's auc_mu: 0.845339	valid_1's multi_logloss: 0.633481
# [24]	training's auc_mu: 0.848415	training's multi_logloss: 0.628255	valid_1's auc_mu: 0.845564	valid_1's multi_logloss: 0.628529
# [25]	training's auc_mu: 0.848734	training's multi_logloss: 0.623492	valid_1's auc_mu: 0.845843	valid_1's multi_logloss: 0.623777
# [26]	training's auc_mu: 0.849119	training's multi_logloss: 0.618946	valid_1's auc_mu: 0.846125	valid_1's multi_logloss: 0.619248
# [27]	training's auc_mu: 0.849509	training's multi_logloss: 0.614508	valid_1's auc_mu: 0.846536	valid_1's multi_logloss: 0.61481
# [28]	training's auc_mu: 0.849789	training's multi_logloss: 0.610243	valid_1's auc_mu: 0.846799	valid_1's multi_logloss: 0.610552
# [29]	training's auc_mu: 0.850086	training's multi_logloss: 0.606118	valid_1's auc_mu: 0.847027	valid_1's multi_logloss: 0.606438
# [30]	training's auc_mu: 0.850382	training's multi_logloss: 0.602132	valid_1's auc_mu: 0.847293	valid_1's multi_logloss: 0.602473
# [31]	training's auc_mu: 0.850586	training's multi_logloss: 0.598304	valid_1's auc_mu: 0.847445	valid_1's multi_logloss: 0.598672
# [32]	training's auc_mu: 0.850782	training's multi_logloss: 0.594632	valid_1's auc_mu: 0.847595	valid_1's multi_logloss: 0.595003
# [33]	training's auc_mu: 0.851014	training's multi_logloss: 0.591078	valid_1's auc_mu: 0.847774	valid_1's multi_logloss: 0.591476
# [34]	training's auc_mu: 0.851208	training's multi_logloss: 0.587637	valid_1's auc_mu: 0.847929	valid_1's multi_logloss: 0.588057
# [35]	training's auc_mu: 0.851429	training's multi_logloss: 0.584338	valid_1's auc_mu: 0.848111	valid_1's multi_logloss: 0.584798
# [36]	training's auc_mu: 0.851628	training's multi_logloss: 0.581136	valid_1's auc_mu: 0.84834	valid_1's multi_logloss: 0.581597
# [37]	training's auc_mu: 0.851901	training's multi_logloss: 0.578054	valid_1's auc_mu: 0.848572	valid_1's multi_logloss: 0.578529
# [38]	training's auc_mu: 0.852158	training's multi_logloss: 0.575048	valid_1's auc_mu: 0.848808	valid_1's multi_logloss: 0.575533
# [39]	training's auc_mu: 0.85239	training's multi_logloss: 0.572187	valid_1's auc_mu: 0.848967	valid_1's multi_logloss: 0.57269
# [40]	training's auc_mu: 0.852621	training's multi_logloss: 0.569388	valid_1's auc_mu: 0.849178	valid_1's multi_logloss: 0.569905
# [41]	training's auc_mu: 0.852824	training's multi_logloss: 0.566693	valid_1's auc_mu: 0.849354	valid_1's multi_logloss: 0.567227
# [42]	training's auc_mu: 0.853034	training's multi_logloss: 0.564077	valid_1's auc_mu: 0.849562	valid_1's multi_logloss: 0.564623
# [43]	training's auc_mu: 0.853243	training's multi_logloss: 0.561546	valid_1's auc_mu: 0.849732	valid_1's multi_logloss: 0.562123
# [44]	training's auc_mu: 0.853419	training's multi_logloss: 0.5591	valid_1's auc_mu: 0.849869	valid_1's multi_logloss: 0.559694
# [45]	training's auc_mu: 0.853624	training's multi_logloss: 0.556725	valid_1's auc_mu: 0.850049	valid_1's multi_logloss: 0.55732
# [46]	training's auc_mu: 0.853856	training's multi_logloss: 0.554435	valid_1's auc_mu: 0.850265	valid_1's multi_logloss: 0.555033
# [47]	training's auc_mu: 0.854032	training's multi_logloss: 0.552231	valid_1's auc_mu: 0.850457	valid_1's multi_logloss: 0.552835
# [48]	training's auc_mu: 0.854196	training's multi_logloss: 0.550107	valid_1's auc_mu: 0.850587	valid_1's multi_logloss: 0.550735
# [49]	training's auc_mu: 0.854414	training's multi_logloss: 0.548004	valid_1's auc_mu: 0.850751	valid_1's multi_logloss: 0.548663
# [50]	training's auc_mu: 0.854607	training's multi_logloss: 0.545971	valid_1's auc_mu: 0.850956	valid_1's multi_logloss: 0.546634
# [51]	training's auc_mu: 0.85486	training's multi_logloss: 0.543962	valid_1's auc_mu: 0.851181	valid_1's multi_logloss: 0.54465
# [52]	training's auc_mu: 0.855022	training's multi_logloss: 0.542071	valid_1's auc_mu: 0.851347	valid_1's multi_logloss: 0.542767
# [53]	training's auc_mu: 0.855199	training's multi_logloss: 0.540223	valid_1's auc_mu: 0.851495	valid_1's multi_logloss: 0.54093
# [54]	training's auc_mu: 0.855355	training's multi_logloss: 0.538438	valid_1's auc_mu: 0.851603	valid_1's multi_logloss: 0.539159
# [55]	training's auc_mu: 0.855527	training's multi_logloss: 0.536711	valid_1's auc_mu: 0.851753	valid_1's multi_logloss: 0.53746
# [56]	training's auc_mu: 0.855726	training's multi_logloss: 0.535	valid_1's auc_mu: 0.851881	valid_1's multi_logloss: 0.535782
# [57]	training's auc_mu: 0.85589	training's multi_logloss: 0.533364	valid_1's auc_mu: 0.851998	valid_1's multi_logloss: 0.534172
# [58]	training's auc_mu: 0.856056	training's multi_logloss: 0.531782	valid_1's auc_mu: 0.85212	valid_1's multi_logloss: 0.532604
# [59]	training's auc_mu: 0.856216	training's multi_logloss: 0.530254	valid_1's auc_mu: 0.85224	valid_1's multi_logloss: 0.531095

# %%
preds_tr = lgbmodel.predict(x_train,)
preds_val = lgbmodel.predict(x_val)

# %%
accuracy_score(y_train, preds_tr)

# %%
accuracy_score(y_val, preds_val)

# %%
# %%time

# lgtrain, lgval = lgb.Dataset(x_train, y_train, categorical_feature = categorical_feats), lgb.Dataset(x_val, y_val, categorical_feature = categorical_feats)

# lgbmodel = lgb.train(params, lgtrain, 200, valid_sets=[lgtrain, lgval], early_stopping_rounds=40, verbose_eval=1)

# %%
len(lgbmodel.feature_importances_)
# Out:
# 195

# %%
lgb.plot_importance(lgbmodel)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# # LGBM Pred

# %%
preds_test = lgbmodel.predict(x_test)

y_test['Target'] = preds_test

y_test

y_test.to_csv("Submissions/DSC_Nexus_UMPW9415_IITM_iterativeImputed.csv", index=0, header=None)

# %% [markdown]
# # Classification

# %%
categorical_feats = x_train.select_dtypes('object').columns.tolist()
for c in categorical_feats:
    x_train[c] = x_train[c].astype('category')
    x_val[c] = x_val[c].astype('category')
    x_test[c] = x_test[c].astype('category')

# %%
datasets = [x_train, x_val, y_train, y_val]

for ind, set in enumerate(datasets):
    datasets[ind] = set.copy()

# %%
# xgtrain = XGB.DMatrix(data = x_train.values, label = y_train.values, enable_categorical=True)       # create dense matrix of training values
# xgval  = XGB.DMatrix(data = x_val.values,  label = y_val.values, enable_categorical=True)        # create dense matrix of val values

# %%
#generate xgboost classifier
xgb = XGB.XGBClassifier(learning_rate =0.1,
                    n_estimators=1000,
                    max_depth=5,
                    min_child_weight=2,
                    gamma=0,
                    subsample=0.5,
                    colsample_bytree=0.6,
                    verbosity=-1,
                   enable_categorical=True,
                   tree_method='hist',
                   early_stopping_rounds=40,
                   eval_metric=['mlogloss', 'auc'])
model = xgb.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_val, y_val)], verbose=1)
preds_tr = xgb.predict(x_train)
preds_val = xgb.predict(x_val)

# %%
preds_tr

# %%
accuracy_score(y_train, preds_tr)

# %%
accuracy_score(y_val, preds_val)

# %% [markdown]
# # Making a submission

# %%
x_test.drop(['D_44', 'D_36'], axis=1, inplace=True)

# %%
preds_test = xgb.predict(x_test)

# %%
y_test['Target'] = preds_test

# %%
y_test

# %%
y_test.to_csv("Submissions/DSC_Nexus_UMPW9415_IITM.csv", index=0, header=None)
