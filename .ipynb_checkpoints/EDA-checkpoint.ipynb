# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
x_train = pd.read_csv("Data/train_allx.csv")
y_train = pd.read_csv("Data/train_y.csv")
x_test = pd.read_csv("Data/val_allx.csv")
y_test = pd.read_csv("Data/Sample_Output.csv", names = ['ID', 'Target'], header=None)

# %%
x_train
# Out:
#                 ID      B_37      S_24       S_4      S_14      B_25  D_38  \
# 0       3337446730  0.006462  0.008118  0.853027  0.556641  1.003906   NaN
# 1       7888784125  0.007748  0.006310  0.758301  0.686035  0.001836   NaN
# 2       9871378905  0.005405  0.005219  0.766602  0.284668  1.002930   NaN
# 3       8891869609  0.004135  0.000032  0.363281  0.004623  0.533691   NaN
# 4       2006443827  0.002968  0.002892  0.757324  0.427734  1.001953   NaN
# ...            ...       ...       ...       ...       ...       ...   ...
# 458908  5845395913  0.003967  0.005070  0.167480  0.421143  0.697266   NaN
# 458909  8870843234  0.006248  0.007683  0.003338  0.006954  1.004883   NaN
# 458910  8163640450  0.004993  0.003204  0.167114  0.289307  0.650879   NaN
# 458911  1220825659  0.002348  0.005432  0.330078  0.003138  0.689941   NaN
# 458912  2326410092  0.009079  0.009773  0.000458  0.004875  1.001953   NaN
#
#             B_30     D_138       P_2  ...  D_43       D_4      D_85      D_78  \
# 0       0.021301  0.511230  1.004883  ...   NaN  0.502441  0.002375  0.008270
# 1       0.088501  0.557129  0.687988  ...   NaN  0.009544  1.002930  0.002613
# 2       0.005821  0.854980  0.927734  ...   NaN  0.008736  0.008751  0.002541
# 3       0.002443  0.526367  0.700684  ...   NaN  0.004646  0.007095  0.000235
# 4       0.008247  0.820312  1.001953  ...   NaN  0.000344  0.005577  0.001367
# ...          ...       ...       ...  ...   ...       ...       ...       ...
# 458908  0.059113  0.526855  0.852051  ...   NaN  0.005363  0.001710  0.001604
# 458909  0.001700  0.575195  0.885254  ...   NaN  0.008728  0.008682  0.008438
# 458910  0.007294  0.406738  0.632324  ...   NaN  0.002733  0.000283  0.009102
# 458911  0.001930  0.417969  0.846191  ...   NaN  0.007492  0.009583  0.001172
# 458912  0.007450  0.602051  0.715332  ...   NaN  0.006264  0.000527  0.002682
#
#             D_42      D_52      D_29       R_1      R_28       S_5
# 0       0.008835  0.001913  1.007812  0.008171  0.008514  0.004307
# 1       0.003374  0.000530  0.006649  0.006798  0.003426  0.009224
# 2       0.009300  0.001654  0.000212  0.007599  0.009224  0.009636
# 3       0.004581  0.004738  0.002653  0.001221  0.009529  0.007523
# 4       0.005760  1.008789  1.003906  0.003401  0.001020  0.000535
# ...          ...       ...       ...       ...       ...       ...
# 458908  0.001387  0.009468  0.000110  0.009346  0.009995  0.001259
# 458909  0.008392  0.006836  0.004223  0.008179  0.004337  0.003376
# 458910  0.000087  0.007229  0.000245  0.007935  0.007233  0.007114
# 458911  0.005016  0.002506  0.009796  0.001634  0.009781  0.003271
# 458912  0.004135  0.006561  0.003550  0.003838  0.003283  0.007168
#
# [458913 rows x 189 columns]

# %%
y_train
# Out:
#         Default_Flag
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 458908             0
# 458909             0
# 458910             0
# 458911             0
# 458912             0
#
# [458913 rows x 1 columns]

# %%
x_test
# Out:
#                 ID      B_37      S_24       S_4      S_14      B_25  D_38  \
# 0       3337446730  0.007183  0.008255  0.768600  0.284000  1.005000   NaN
# 1       7888784125  0.002203  0.008860  0.479000  0.697800  0.149800   NaN
# 2       9871378905  0.001282  0.000458  0.006035  0.002628  0.008965   NaN
# 3       8891869609  0.008720  0.006454  0.752400  0.686000  0.052980   NaN
# 4       2006443827  0.000901  0.008650  0.486300  0.696300  0.530300   NaN
# ...            ...       ...       ...       ...       ...       ...   ...
# 467961  5512100313  0.004086  0.000147  0.329600  0.002620  0.294400   NaN
# 467962  2488191588  0.008910  0.000919  0.009230  0.006115  1.003000   NaN
# 467963  4896427435  0.009766  0.008220  0.323700  0.284200  0.098800   NaN
# 467964  9244915426  0.009980  0.005333  0.486000  0.510700  0.696000   NaN
# 467965  4727936004  0.004950  0.001845  0.007584  0.003288  0.476600   NaN
#
#            B_30   D_138      P_2  ...  D_43       D_4      D_85      D_78  \
# 0       0.01746  0.3623  0.84130  ...   NaN  0.005062  0.009926  0.001636
# 1       0.18530  0.1719  0.51300  ...   NaN  0.000115  0.004593  0.007595
# 2       0.61130  0.2656  0.35130  ...   NaN  0.008835  0.002188  0.005707
# 3       0.63600  0.2722  0.30710  ...   NaN  0.004517  0.009030  0.009620
# 4       0.65300  0.6680  0.49170  ...   NaN  0.006897  0.004430  0.006410
# ...         ...     ...      ...  ...   ...       ...       ...       ...
# 467961  0.24620  0.1800  0.03317  ...   NaN  0.007103  0.008780  0.007590
# 467962  0.00838  0.5503  0.84200  ...   NaN  0.009320  0.000625  0.006428
# 467963  0.56000  0.1959  0.15650  ...   NaN  0.009090  0.009600  0.004220
# 467964  0.06640  0.8833  0.82500  ...   NaN  0.006916  0.001587  0.002142
# 467965  0.00735  0.6390  0.78800  ...   NaN  0.001489  0.001667  0.007294
#
#             D_42      D_52      D_29       R_1      R_28       S_5
# 0       0.004040  0.006800  0.009550  0.008790  0.005405  0.002151
# 1       0.002203  0.004673  0.008500  0.003622  0.007015  0.009514
# 2       0.002361  0.005180  0.002550  0.002836  0.007294  1.007000
# 3       0.008270  0.008020  0.003286  0.000770  0.009120  0.003626
# 4       0.009770  0.006730  0.009640  0.004060  0.003770  0.002522
# ...          ...       ...       ...       ...       ...       ...
# 467961  0.009440  0.003723  0.001698  0.004616  0.005566  0.004290
# 467962  0.003838  0.005753  0.007400  0.008780  0.002214  0.006184
# 467963  0.002270  0.000102  0.007713  0.003700  0.008320  0.005623
# 467964  0.006580  0.009056  0.008064  0.001599  0.006733  0.004776
# 467965  0.009865  0.006390  0.002014  0.008766  0.000485  0.002613
#
# [467966 rows x 189 columns]

# %%
y_test
# Out:
#                 ID  Target
# 0       3337446730       1
# 1       7888784125       0
# 2       9871378905       2
# 3       8891869609       0
# 4       2006443827       0
# ...            ...     ...
# 467961  5512100313       1
# 467962  2488191588       0
# 467963  4896427435       2
# 467964  9244915426       0
# 467965  4727936004       0
#
# [467966 rows x 2 columns]

# %%
# Dropping ID column

x_train.drop('ID', axis=1, inplace=True)
x_test.drop('ID', axis=1, inplace=True)

# %%
data = x_train.copy()
data['Target'] = y_train

# %% [markdown]
# ## Checking the Target Column

# %%
data['Target'].value_counts()
# Out:
# 0    340085
# 2     46424
# 3     37903
# 1     34501
# Name: Target, dtype: int64

# %% [markdown]
# # EDA

# %%
# figure out the data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458913 entries, 0 to 458912
# Columns: 189 entries, B_37 to Target
# dtypes: float64(184), int64(3), object(2)
# memory usage: 661.7+ MB

# %%
data.dtypes
# Out:
# B_37      float64
# S_24      float64
# S_4       float64
# S_14      float64
# B_25      float64
#            ...
# D_29      float64
# R_1       float64
# R_28      float64
# S_5       float64
# Target      int64
# Length: 189, dtype: object

# %%
data.dtypes[data.dtypes != 'float64']
# Out:
# D_36      object
# D_44      object
# B_41       int64
# D_130      int64
# Target     int64
# dtype: object

# %% [markdown]
# ### Int Datatypes

# %%
data['B_41']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 458908    1
# 458909    1
# 458910    1
# 458911    1
# 458912    1
# Name: B_41, Length: 458913, dtype: int64

# %%
data['B_41'].value_counts()
# Out:
# 1    456295
# 0      2618
# Name: B_41, dtype: int64

# %%
data['D_130']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 458908    1
# 458909    1
# 458910    1
# 458911    1
# 458912    0
# Name: D_130, Length: 458913, dtype: int64

# %%
data['D_130'].value_counts()
# Out:
# 1    355057
# 0    103856
# Name: D_130, dtype: int64

# %% [markdown]
# ### Checking the Object dtyes

# %%
data['D_36']
# Out:
# 0         CO
# 1         CL
# 2         CO
# 3         CR
# 4         XM
#           ..
# 458908    CO
# 458909    CO
# 458910    CR
# 458911    CO
# 458912    CO
# Name: D_36, Length: 458913, dtype: object

# %%
data['D_36'].value_counts()
# Out:
# CO    344890
# CR     73178
# CL     35271
# XZ      3263
# XM      1503
# XL       808
# Name: D_36, dtype: int64

# %%
data['D_44']
# Out:
# 0         O
# 1         O
# 2         O
# 3         O
# 4         O
#          ..
# 458908    O
# 458909    U
# 458910    O
# 458911    O
# 458912    U
# Name: D_44, Length: 458913, dtype: object

# %%
data['D_44'].value_counts()
# Out:
# O    244622
# U    132722
# R     71532
# Name: D_44, dtype: int64

# %% [markdown]
# ## Null Values

# %%
data.isnull().sum()[data.isnull().sum() > 0]
# Out:
# D_38    458086
# P_2       2969
# S_7      84970
# S_25     84970
# D_99     30377
#          ...
# R_7     407770
# D_96    455235
# D_39    455235
# D_43    456286
# D_4      12807
# Length: 109, dtype: int64

# %%
# Percentage of Null Values
percentNull = data.isnull().sum()[data.isnull().sum() > 0] / len(data) *100
percentNull
# Out:
# D_38    99.819792
# P_2      0.646964
# S_7     18.515492
# S_25    18.515492
# D_99     6.619337
#           ...
# R_7     88.855622
# D_96    99.198541
# D_39    99.198541
# D_43    99.427560
# D_4      2.790725
# Length: 109, dtype: float64

# %%
(percentNull[percentNull > 50]).index
# Out:
# Index(['D_38', 'B_29', 'B_26', 'D_68', 'D_110', 'D_17', 'D_106', 'D_48',
#        'D_92', 'R_8', 'D_73', 'D_105', 'D_10', 'D_141', 'D_11', 'D_142',
#        'D_31', 'D_95', 'B_7', 'B_22', 'D_80', 'D_97', 'D_12', 'D_132', 'D_114',
#        'R_7', 'D_96', 'D_39', 'D_43'],
#       dtype='object')

# %%
# x_train.drop((percentNull[percentNull > 50]).index, axis=1, inplace = True)
# x_test.drop((percentNull[percentNull > 50]).index, axis=1, inplace = True)

# %%
# x_train.to_csv('Data/train_x_null<50_notImputed.csv', index=0)
# x_test.to_csv('Data/test_x_null<50_notImputed.csv', index=0)

# %% [markdown]
# # Correlation

# %%
corr_mat = data.corr()

# %%
corr_mat
# Out:
#             B_37      S_24       S_4      S_14      B_25      D_38      B_30  \
# B_37    1.000000  0.000208 -0.133955 -0.123188 -0.190071  0.137502  0.150475
# S_24    0.000208  1.000000  0.002101  0.005028 -0.004990 -0.020312  0.004294
# S_4    -0.133955  0.002101  1.000000  0.702917  0.130203 -0.314342 -0.082488
# S_14   -0.123188  0.005028  0.702917  1.000000  0.105579 -0.304685 -0.067683
# B_25   -0.190071 -0.004990  0.130203  0.105579  1.000000 -0.022786 -0.599462
# ...          ...       ...       ...       ...       ...       ...       ...
# D_29   -0.054844 -0.000868  0.302343  0.292491  0.276612 -0.068022 -0.177687
# R_1    -0.004010  0.001671 -0.003485 -0.000378 -0.019764  0.005201  0.017612
# R_28    0.059296 -0.000809 -0.075418 -0.070131 -0.147428  0.148926  0.157958
# S_5    -0.014595  0.068774 -0.022189 -0.009027 -0.099145  0.180793  0.123810
# Target  0.114813  0.008440 -0.162704 -0.135801 -0.485315  0.059505  0.478168
#
#            D_138       P_2       S_7  ...       D_4      D_85      D_78  \
# B_37   -0.043622 -0.151145  0.019732  ... -0.039010 -0.027850 -0.020930
# S_24   -0.001027 -0.003504  0.017230  ... -0.000884 -0.002340 -0.000875
# S_4     0.145127  0.216406 -0.394377  ...  0.232922  0.182402  0.096829
# S_14    0.087860  0.160890 -0.202898  ...  0.268209  0.282127  0.099089
# B_25    0.191255  0.632005 -0.262576  ...  0.148146  0.048440  0.107211
# ...          ...       ...       ...  ...       ...       ...       ...
# D_29    0.167224  0.264038 -0.193297  ...  0.199824  0.142784  0.177895
# R_1    -0.018366 -0.011534  0.072507  ... -0.006352 -0.003566 -0.003481
# R_28   -0.066133 -0.321730  0.087160  ... -0.035266 -0.022388 -0.017449
# S_5    -0.057867 -0.109586  0.211830  ... -0.023809 -0.010544 -0.013469
# Target -0.264793 -0.562642  0.296676  ... -0.120557 -0.064124 -0.066179
#
#             D_42      D_52      D_29       R_1      R_28       S_5    Target
# B_37   -0.003609 -0.046704 -0.054844 -0.004010  0.059296 -0.014595  0.114813
# S_24   -0.000766 -0.003170 -0.000868  0.001671 -0.000809  0.068774  0.008440
# S_4     0.004904  0.335297  0.302343 -0.003485 -0.075418 -0.022189 -0.162704
# S_14   -0.004041  0.404842  0.292491 -0.000378 -0.070131 -0.009027 -0.135801
# B_25    0.023235  0.261876  0.276612 -0.019764 -0.147428 -0.099145 -0.485315
# ...          ...       ...       ...       ...       ...       ...       ...
# D_29    0.019009  0.309433  1.000000 -0.008816 -0.048454 -0.034075 -0.175234
# R_1    -0.002333 -0.007351 -0.008816  1.000000 -0.002823  0.015356  0.023157
# R_28   -0.007824 -0.040594 -0.048454 -0.002823  1.000000  0.020283  0.149427
# S_5    -0.007072 -0.026582 -0.034075  0.015356  0.020283  1.000000  0.118771
# Target -0.031691 -0.142963 -0.175234  0.023157  0.149427  0.118771  1.000000
#
# [187 rows x 187 columns]

# %%
# corr_mat.reset_index(inplace=True)
# corr_mat.to_feather('Helpers/corr_mat.ftr')

# %%
corr_mat['Target'] = corr_mat['Target'].abs()
corr_mat[['index', 'Target']].sort_values(by='Target', ascending=False).head(10)
# Out:
#       index    Target
# 186  Target  1.000000
# 8       P_2  0.562642
# 101    D_40  0.524474
# 31      B_9  0.489996
# 4      B_25  0.485315
# 6      B_30  0.478168
# 12     D_99  0.466598
# 110    D_22  0.465842
# 30      B_5  0.458598
# 114    D_56  0.453967

# %% [markdown]
# # Imputing the null values

# %%
for col in x_train.columns:
    if x_train[col].dtype != 'object':
        mean = x_train[col].mean(skipna=True)
        x_train[col]=x_train[col].fillna(mean)
        x_test[col]=x_test[col].fillna(mean)

# %%
for col in x_train.columns:
    if x_train[col].dtype == 'object':
        mode = x_train[col].mode(dropna=True)[0]
        x_train[col]=x_train[col].fillna(mode)
        x_test[col]=x_test[col].fillna(mode)

# %%
x_train.isnull().sum()[x_train.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# x_train.drop(['D_44', 'D_36'], axis=1, inplace=True)

# %% [markdown]
# # Saving the Data Files

# %%
x_train.to_csv('Data/train__mean_mode_Imputed.csv', index=0)
x_test.to_csv('Data/test__mean_mode_Imputed.csv', index=0)
